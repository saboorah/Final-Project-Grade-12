# %%
#creates background
#creates & deals deck to the 2 players

import random
import pygame
from pygameRogers import Game
from pygameRogers import Room
from pygameRogers import GameObject
from pygameRogers import TextRectangle

#Craete a new game-------------------------------------------------------------
g = Game(900,500)

#Color
BLUE = (0,143,213) 
BLACK = (0,0,0) 
WHITE = (255,255,255) 
GREEN = (0,255,0)

#Create Resources--------------------------------------------------------------
gameFont = g.makeFont("Arial",38)
gameBackground = g.makeBackground(BLUE)

diamondPics = []
for i in range (2,15):
    diamondPics.append(g.makeSpriteImage("Cards\DIAMONDS" + str(i) + ".jpg"))
    
heartPics = []
for i in range (2,15):
    heartPics.append(g.makeSpriteImage("Cards\HEARTS" + str(i) + ".jpg"))
    
spadePics = []
for i in range (2,15):
    spadePics.append(g.makeSpriteImage("Cards\SPADES" + str(i) + ".jpg"))
    
clubPics = []
for i in range (2,15):
    clubPics.append(g.makeSpriteImage("Cards\CLUBS" + str(i) + ".jpg"))
    
topCard = g.makeSpriteImage("Cards\TOP.jpg")

#Create Room-------------------------------------------------------------------
r1  = Room("Game",gameBackground)
g.addRoom(r1)

#Classes for Game objects------------------------------------------------------
class Card (GameObject):
    def __init__(self, picture, value, suit):
        GameObject.__init__(self,picture)
        
        #Attributes
        self.value = value # 2-14
        self.suit = suit # H, D, C, S
        
        
    def __str__(self):
        return str(self.value) + self.suit

class CardDeck(GameObject):
    def __init__(self):
        GameObject.__init__(self)
        
        self.deck = []
        self.p1_deck = []
        self.p2_deck = []
        
        for i in range (0, len(diamondPics)):
            c = Card(diamondPics[i], (i+2), "D")
            self.deck.append(c)
            
        for i in range (0, len(heartPics)):
            c = Card(heartPics[i], (i+2), "H")
            self.deck.append(c)
            
        for i in range (0, len(clubPics)):
            c = Card(clubPics[i], (i+2), "C")
            self.deck.append(c)
            
        for i in range (0, len(spadePics)):
            c = Card(spadePics[i], (i+2), "S")
            self.deck.append(c)

        random.shuffle(self.deck)   
        
        #distribute the cards amoung the 2 players
        for i in range (0,len(self.deck)//2):
            self.p1_deck.append(self.deck[i])
            
        for i in range (len(self.deck)//2,len(self.deck)):
            self.p2_deck.append(self.deck[i])
        
        
        
    def __str__(self):
        s = ""
        
        for card in self.p1_deck:
            s += str(card) + " "
        s = "Deck1:\n" + s + "\n"
        
    
        s2 = ""
        
        for card in self.p2_deck:
            s2 += str(card) + " "
        s2 = "Deck2:\n" + s2 + "\n"
        
        return s + "\t\t\t\t" + s2
    
class PlayerDeck(GameObject):
    #display
    def __init__(self, picture, xPos, yPos, player_deck):
        GameObject.__init__(self,picture)
        
        self.rect.x = xPos
        self.rect.y = yPos
        
        self.player_deck = player_deck
        
    def __str__(self):
        s = ""
        
        for card in self.player_deck:
            s += str(card) + " "
        s = "Deck:\n" + s + "\n"
        return s
    

        
    
    
#Initialize Objects and add them to the room-----------------------------------
d = CardDeck()
r1.addObject(d)

p1_Deck = PlayerDeck(topCard, 70, 50, d.p1_deck)
p2_Deck = PlayerDeck(topCard, 70, 350, d.p2_deck)

r1.addObject(p1_Deck)
r1.addObject(p2_Deck)


print(p1_Deck)
print(p2_Deck)

#Start Game--------------------------------------------------------------------
g.start()

#Game Loop
while g.running:
    
    #Limit the game excecution framerate
    dt = g.clock.tick(60)
    
    #Check for events 
    for event in pygame.event.get():
        
        #Quit if user click [x]
        if event.type == pygame.QUIT:
            g.stop()
            
    #Update the gamestate of all objects
 #   g.currentRoom().updateObjects()
    
    #Render the background to the window surface
    g.currentRoom().renderBackground(g)
    
    #Render the object images to the background
    g.currentRoom().renderObjects(g)
    
    #Draw everything on the screen
    pygame.display.flip()
    
pygame.quit()
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.8.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Deck:
# 12H 11C 8D 4S 2S 6C 3D 14H 4H 2D 5H 4D 14D 11H 5S 12D 13C 10C 14C 6D 11D 7C 3S 10S 8S 7S
#
# Deck:
# 8H 13S 2C 3H 5D 13H 9C 9D 10H 9H 4C 8C 12C 13D 5C 6S 9S 2H 6H 7D 14S 12S 7H 3C 11S 10D

# %%
#cards are flipped, removed from deck
import random
import pygame
from pygameRogers import Game
from pygameRogers import Room
from pygameRogers import GameObject
from pygameRogers import TextRectangle

#Craete a new game-------------------------------------------------------------
g = Game(900,500)

#Color
BLUE = (0,143,213) 
BLACK = (0,0,0) 
WHITE = (255,255,255) 
GREEN = (0,255,0)

#Create Resources--------------------------------------------------------------
gameFont = g.makeFont("Arial",38)
gameBackground = g.makeBackground(BLUE)

diamondPics = []
for i in range (2,15):
    diamondPics.append(g.makeSpriteImage("Cards\DIAMONDS" + str(i) + ".jpg"))
    
heartPics = []
for i in range (2,15):
    heartPics.append(g.makeSpriteImage("Cards\HEARTS" + str(i) + ".jpg"))
    
spadePics = []
for i in range (2,15):
    spadePics.append(g.makeSpriteImage("Cards\SPADES" + str(i) + ".jpg"))
    
clubPics = []
for i in range (2,15):
    clubPics.append(g.makeSpriteImage("Cards\CLUBS" + str(i) + ".jpg"))
    
topCard = g.makeSpriteImage("Cards\TOP.jpg")

#Create Room-------------------------------------------------------------------
r1  = Room("Game",gameBackground)
g.addRoom(r1)

#Classes for Game objects------------------------------------------------------
class Card (GameObject):
    def __init__(self, picture, value, suit):
        GameObject.__init__(self,picture)
        
        #Attributes
        self.value = value # 2-14
        self.suit = suit # H, D, C, S
        
        
    def __str__(self):
        return str(self.value) + self.suit

class CardDeck(GameObject):
    def __init__(self):
        GameObject.__init__(self)
        
        self.deck = []
        self.p1_deck = []
        self.p2_deck = []
        
        for i in range (0, len(diamondPics)):
            c = Card(diamondPics[i], (i+2), "D")
            self.deck.append(c)
            
        for i in range (0, len(heartPics)):
            c = Card(heartPics[i], (i+2), "H")
            self.deck.append(c)
            
        for i in range (0, len(clubPics)):
            c = Card(clubPics[i], (i+2), "C")
            self.deck.append(c)
            
        for i in range (0, len(spadePics)):
            c = Card(spadePics[i], (i+2), "S")
            self.deck.append(c)

        random.shuffle(self.deck)   
        
        #distribute the cards amoung the 2 players
        for i in range (0,len(self.deck)//2):
            self.p1_deck.append(self.deck[i])
            
        for i in range (len(self.deck)//2,len(self.deck)):
            self.p2_deck.append(self.deck[i])
        
        
        
    def __str__(self):
        s = ""
        
        for card in self.p1_deck:
            s += str(card) + " "
        s = "Deck1:\n" + s + "\n"
        
    
        s2 = ""
        
        for card in self.p2_deck:
            s2 += str(card) + " "
        s2 = "Deck2:\n" + s2 + "\n"
        
        return s + "\t\t\t\t" + s2
    
class PlayerDeck(GameObject):
    #display
    def __init__(self, picture, xPos, yPos, player_deck):
        GameObject.__init__(self,picture)
        
        self.rect.x = xPos
        self.rect.y = yPos
        
        self.player_deck = player_deck
        
    def __str__(self):
        s = ""
        
        for card in self.player_deck:
            s += str(card) + " "
        s = "Deck:\n" + s + "\n"
        return s
    
    def update(self):
        self.checkMousePressedOnMe(event)
        
        if self.mouseHasPressedOnMe and event.type == pygame.MOUSEBUTTONUP:
            
            card = p1_Deck.get_top_card()
            p1Card.flipCardOver(card)
            
            card2 = p2_Deck.get_top_card()
            p2Card.flipCardOver(card2)
            
            print(p1_Deck)
            print(p1Card)
            print(p2Card)
            print(p2_Deck)
            


             
            self.mouseHasPressedOnMe = False
    
    def get_top_card(self):
        
        if len(self.player_deck) > 0:
            c = self.player_deck[0]
            del self.player_deck[0]
            
            if len(self.player_deck) == 0:
                self.kill()
                    
        return c
    

class FlipedCard(GameObject):
    
    def __init__(self,xPos,yPos):
        GameObject.__init__(self)
        
        self.xPos = xPos
        self.yPos = yPos
        self.clicked = []
     #   self.flipped = False
        
        
    def flipCardOver(self,card):
        self.clicked.append(card)
        
        card.rect.x = self.xPos
        card.rect.y = self.yPos
        
        r1.addObject(card)
     #   self.flipped = True
     
    def __str__(self):
         s = " cards flipped: "
         
         if len(self.clicked) > 0:
             for i in range (0,len(self.clicked)):
                 s += str(self.clicked[i]) + " "
             
         return s       
        
    
    
#Initialize Objects and add them to the room-----------------------------------
d = CardDeck()
r1.addObject(d)

p1_Deck = PlayerDeck(topCard, 70, 50, d.p1_deck)
p2_Deck = PlayerDeck(topCard, 70, 350, d.p2_deck)

r1.addObject(p1_Deck)
r1.addObject(p2_Deck)

p1Card = FlipedCard(185,50)
p2Card = FlipedCard(185,350)

r1.addObject(p1Card)
r1.addObject(p2Card)




#Start Game--------------------------------------------------------------------
g.start()

#Game Loop
while g.running:
    
    #Limit the game excecution framerate
    dt = g.clock.tick(60)
    
    #Check for events 
    for event in pygame.event.get():
        
        #Quit if user click [x]
        if event.type == pygame.QUIT:
            g.stop()
            
    #Update the gamestate of all objects
    g.currentRoom().updateObjects()
    
    #Render the background to the window surface
    g.currentRoom().renderBackground(g)
    
    #Render the object images to the background
    g.currentRoom().renderObjects(g)
    
    #Draw everything on the screen
    pygame.display.flip()
    
pygame.quit()
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.8.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# Deck:
# 8S 12D 10C 2S 12C 2D 11H 6D 8H 5H 13H 11C 3D 12H 13C 3S 9C 11D 7C 10S 14C 6S 5S 7S 5C
#
#  cards flipped: 9D
#  cards flipped: 14S
# Deck:
# 3C 6H 4S 11S 7D 8D 9S 14D 10H 2H 13D 2C 8C 14H 10D 7H 4H 5D 4C 4D 3H 6C 13S 12S 9H
#
# Deck:
# 12D 10C 2S 12C 2D 11H 6D 8H 5H 13H 11C 3D 12H 13C 3S 9C 11D 7C 10S 14C 6S 5S 7S 5C
#
#  cards flipped: 9D 8S
#  cards flipped: 14S 3C
# Deck:
# 6H 4S 11S 7D 8D 9S 14D 10H 2H 13D 2C 8C 14H 10D 7H 4H 5D 4C 4D 3H 6C 13S 12S 9H
#
# Deck:
# 10C 2S 12C 2D 11H 6D 8H 5H 13H 11C 3D 12H 13C 3S 9C 11D 7C 10S 14C 6S 5S 7S 5C
#
#  cards flipped: 9D 8S 12D
#  cards flipped: 14S 3C 6H
# Deck:
# 4S 11S 7D 8D 9S 14D 10H 2H 13D 2C 8C 14H 10D 7H 4H 5D 4C 4D 3H 6C 13S 12S 9H
#
# Deck:
# 2S 12C 2D 11H 6D 8H 5H 13H 11C 3D 12H 13C 3S 9C 11D 7C 10S 14C 6S 5S 7S 5C
#
#  cards flipped: 9D 8S 12D 10C
#  cards flipped: 14S 3C 6H 4S
# Deck:
# 11S 7D 8D 9S 14D 10H 2H 13D 2C 8C 14H 10D 7H 4H 5D 4C 4D 3H 6C 13S 12S 9H
#
# Deck:
# 12C 2D 11H 6D 8H 5H 13H 11C 3D 12H 13C 3S 9C 11D 7C 10S 14C 6S 5S 7S 5C
#
#  cards flipped: 9D 8S 12D 10C 2S
#  cards flipped: 14S 3C 6H 4S 11S
# Deck:
# 7D 8D 9S 14D 10H 2H 13D 2C 8C 14H 10D 7H 4H 5D 4C 4D 3H 6C 13S 12S 9H
#
# Deck:
# 2D 11H 6D 8H 5H 13H 11C 3D 12H 13C 3S 9C 11D 7C 10S 14C 6S 5S 7S 5C
#
#  cards flipped: 9D 8S 12D 10C 2S 12C
#  cards flipped: 14S 3C 6H 4S 11S 7D
# Deck:
# 8D 9S 14D 10H 2H 13D 2C 8C 14H 10D 7H 4H 5D 4C 4D 3H 6C 13S 12S 9H
#
# Deck:
# 11H 6D 8H 5H 13H 11C 3D 12H 13C 3S 9C 11D 7C 10S 14C 6S 5S 7S 5C
#
#  cards flipped: 9D 8S 12D 10C 2S 12C 2D
#  cards flipped: 14S 3C 6H 4S 11S 7D 8D
# Deck:
# 9S 14D 10H 2H 13D 2C 8C 14H 10D 7H 4H 5D 4C 4D 3H 6C 13S 12S 9H

# %%
#cards go into respective discard piles

import random
import pygame
from pygameRogers import Game
from pygameRogers import Room
from pygameRogers import GameObject
from pygameRogers import TextRectangle

#Craete a new game-------------------------------------------------------------
g = Game(700,500) #w/ war x = 900 pix

#Color
BLUE = (0,143,213) 
BLACK = (0,0,0) 
WHITE = (255,255,255) 
PASTEL_GREEN = (210,249,237)

#Create Resources--------------------------------------------------------------
gameFont1 = g.makeFont("Arial",22)
gameBackground = g.makeBackground(BLUE)

diamondPics = []
for i in range (2,15):
    diamondPics.append(g.makeSpriteImage("Cards\DIAMONDS" + str(i) + ".jpg"))
    
heartPics = []
for i in range (2,15):
    heartPics.append(g.makeSpriteImage("Cards\HEARTS" + str(i) + ".jpg"))
    
spadePics = []
for i in range (2,15):
    spadePics.append(g.makeSpriteImage("Cards\SPADES" + str(i) + ".jpg"))
    
clubPics = []
for i in range (2,15):
    clubPics.append(g.makeSpriteImage("Cards\CLUBS" + str(i) + ".jpg"))
    
topCard = g.makeSpriteImage("Cards\TOP.jpg")

#Create Room-------------------------------------------------------------------
r1  = Room("Game",gameBackground)
g.addRoom(r1)

#Classes for Game objects------------------------------------------------------
class Card (GameObject):
    def __init__(self, picture, value, suit):
        GameObject.__init__(self,picture)
        
        #Attributes
        self.value = value # 2-14
        self.suit = suit # H, D, C, S
        
    def update(self):
        self.checkMousePressedOnMe(event)
        
        if self.mouseHasPressedOnMe and event.type == pygame.MOUSEBUTTONUP:
             
            lastCard = len(p1Card.played) - 1 
            card_p1_played = p1Card.played[lastCard]
            card_p2_played = p2Card.played[lastCard]
            
            if card_p1_played.value > card_p2_played.value:
                
                p1Card.discardCard(card_p1_played)
                p2Card.discardCard(card_p2_played)
                
                p1_discard.addCard(card_p1_played)
                p1_discard.addCard(card_p2_played)
                
                
                print("Player 1 ",p1_discard)
                
            elif card_p1_played.value < card_p2_played.value:
                
                p1Card.discardCard(card_p1_played)
                p2Card.discardCard(card_p2_played)
                
                p2_discard.addCard(card_p1_played)
                p2_discard.addCard(card_p2_played)
                
                
                print("Player 2 ",p2_discard)
                
            else:
                p1Card.discardCard(card_p1_played)
                p2Card.discardCard(card_p2_played)
                
                p1_discard.addCard(card_p1_played)
                p2_discard.addCard(card_p2_played)
            
                print("Player 1 ",p1_discard)
                print("Player 2 ",p2_discard)
            
            self.mouseHasPressedOnMe = False
            
        
    def __str__(self):
        return str(self.value) + self.suit

class CardDeck(GameObject):
    def __init__(self):
        GameObject.__init__(self)
        
        self.deck = []
        self.p1_deck = []
        self.p2_deck = []
        
        for i in range (0, len(diamondPics)):
            c = Card(diamondPics[i], (i+2), "D")
            self.deck.append(c)
            
        for i in range (0, len(heartPics)):
            c = Card(heartPics[i], (i+2), "H")
            self.deck.append(c)
            
        for i in range (0, len(clubPics)):
            c = Card(clubPics[i], (i+2), "C")
            self.deck.append(c)
            
        for i in range (0, len(spadePics)):
            c = Card(spadePics[i], (i+2), "S")
            self.deck.append(c)

        random.shuffle(self.deck)   
        
        #distribute the cards amoung the 2 players
        for i in range (0,len(self.deck)//2):
            self.p1_deck.append(self.deck[i])
            
        for i in range (len(self.deck)//2,len(self.deck)):
            self.p2_deck.append(self.deck[i])
        
        
        
    def __str__(self):
        s = ""
        
        for card in self.p1_deck:
            s += str(card) + " "
        s = "Deck1:\n" + s + "\n"
        
    
        s2 = ""
        
        for card in self.p2_deck:
            s2 += str(card) + " "
        s2 = "Deck2:\n" + s2 + "\n"
        
        return s + "\t\t\t\t" + s2
    
class PlayerDeck(GameObject):
    #display
    def __init__(self, picture, xPos, yPos, player_deck):
        GameObject.__init__(self,picture)
        
        self.rect.x = xPos
        self.rect.y = yPos
        
        self.player_deck = player_deck
        
    def __str__(self):
        s = ""
        
        for card in self.player_deck:
            s += str(card) + " "
        s = "Deck:\n" + s + "\n"
        return s
    
    def update(self):
        self.checkMousePressedOnMe(event)
        
        if self.mouseHasPressedOnMe and event.type == pygame.MOUSEBUTTONUP:
            
            card = p1_Deck.get_top_card()
            p1Card.flipCardOver(card)
            
            card2 = p2_Deck.get_top_card()
            p2Card.flipCardOver(card2)
            
            print(p1_Deck)
            print(p2_Deck)
            print(p1Card)
            print(p2Card)

          
            self.mouseHasPressedOnMe = False
    
    def get_top_card(self):
        
        if len(self.player_deck) > 0:
            c = self.player_deck[0]
            del self.player_deck[0]
            
            if len(self.player_deck) == 0:
                self.kill()
                    
        return c
    

class FlipedCard(GameObject):
    
    def __init__(self,xPos,yPos):
        GameObject.__init__(self)
        
        self.xPos = xPos
        self.yPos = yPos
        self.played = []
        
        
    def flipCardOver(self,card):
        self.played.append(card)        
        
        card.rect.x = self.xPos
        card.rect.y = self.yPos
        
        r1.addObject(card)
        
    def discardCard(self, card):
        
        for c in self.played:
            c.kill()
            
       # self.played.remove(card)
     
     
    def __str__(self):
         s = " cards flipped: "
         
         if len(self.played) > 0:
             for i in range (0,len(self.played)):
                 s += str(self.played[i]) + " "
             
         return s       
        
class Discardpile(GameObject):
    def __init__(self,xPos,yPos):
        GameObject.__init__(self)
        
        self.playedCards = []
        
        self.rect.x = xPos
        self.rect.y = yPos
        
    def addCard(self,card):
        self.playedCards.append(card)
        
        self.image = card.image
    
        
        
    def __str__(self):
        s = ""
        if len(self.playedCards) > 0:
            for card in self.playedCards:
                s += str(card) + " "
        s = "discarded: " + s
        return s
    
    
#Initialize Objects and add them to the room-----------------------------------

play_card_label = TextRectangle("Click either deck to flip cards",15,15,gameFont1,PASTEL_GREEN)
discard_card_label = TextRectangle("Click the card to collect it",145,200,gameFont1,PASTEL_GREEN)

r1.addObject(play_card_label)
r1.addObject(discard_card_label)

d = CardDeck()
r1.addObject(d)

p1_Deck = PlayerDeck(topCard, 70, 50, d.p1_deck)
p2_Deck = PlayerDeck(topCard, 70, 350, d.p2_deck)

r1.addObject(p1_Deck)
r1.addObject(p2_Deck)

p1Card = FlipedCard(185,50)
p2Card = FlipedCard(185,350)

r1.addObject(p1Card)
r1.addObject(p2Card)

p1_discard = Discardpile(430,50) #when screen 900 pix, x = 730
p2_discard = Discardpile(430,350)
r1.addObject(p2_discard)
r1.addObject(p1_discard)


#Start Game--------------------------------------------------------------------
g.start()

#Game Loop
while g.running:
    
    #Limit the game excecution framerate
    dt = g.clock.tick(60)
    
    #Check for events 
    for event in pygame.event.get():
        
        #Quit if user click [x]
        if event.type == pygame.QUIT:
            g.stop()
            
    #Update the gamestate of all objects
    g.currentRoom().updateObjects()
    
    #Render the background to the window surface
    g.currentRoom().renderBackground(g)
    
    #Render the object images to the background
    g.currentRoom().renderObjects(g)
    
    #Draw everything on the screen
    pygame.display.flip()
    
pygame.quit()
# Out:
# Deck:
# 5H 2C 5C 3C 5D 10C 14H 12S 13C 7D 9D 13H 2D 8C 14D 4D 12H 9S 4S 6C 13S 9C 4H 14S 3S
#
# Deck:
# 5S 10S 11H 12C 6H 8D 6D 6S 2H 12D 7C 9H 11D 3D 10H 11S 13D 2S 8H 3H 11C 14C 8S 4C 10D
#
#  cards flipped: 7H
#  cards flipped: 7S
# Player 1  discarded: 7H
# Player 2  discarded: 7S
# Deck:
# 2C 5C 3C 5D 10C 14H 12S 13C 7D 9D 13H 2D 8C 14D 4D 12H 9S 4S 6C 13S 9C 4H 14S 3S
#
# Deck:
# 10S 11H 12C 6H 8D 6D 6S 2H 12D 7C 9H 11D 3D 10H 11S 13D 2S 8H 3H 11C 14C 8S 4C 10D
#
#  cards flipped: 7H 5H
#  cards flipped: 7S 5S
# Player 1  discarded: 7H 5H
# Player 2  discarded: 7S 5S
# Player 1  discarded: 7H 5H 5H
# Player 2  discarded: 7S 5S 5S
# Deck:
# 5C 3C 5D 10C 14H 12S 13C 7D 9D 13H 2D 8C 14D 4D 12H 9S 4S 6C 13S 9C 4H 14S 3S
#
# Deck:
# 11H 12C 6H 8D 6D 6S 2H 12D 7C 9H 11D 3D 10H 11S 13D 2S 8H 3H 11C 14C 8S 4C 10D
#
#  cards flipped: 7H 5H 2C
#  cards flipped: 7S 5S 10S
# Player 2  discarded: 7S 5S 5S 2C 10S
# Deck:
# 3C 5D 10C 14H 12S 13C 7D 9D 13H 2D 8C 14D 4D 12H 9S 4S 6C 13S 9C 4H 14S 3S
#
# Deck:
# 12C 6H 8D 6D 6S 2H 12D 7C 9H 11D 3D 10H 11S 13D 2S 8H 3H 11C 14C 8S 4C 10D
#
#  cards flipped: 7H 5H 2C 5C
#  cards flipped: 7S 5S 10S 11H
# Player 2  discarded: 7S 5S 5S 2C 10S 5C 11H
# Deck:
# 5D 10C 14H 12S 13C 7D 9D 13H 2D 8C 14D 4D 12H 9S 4S 6C 13S 9C 4H 14S 3S
#
# Deck:
# 6H 8D 6D 6S 2H 12D 7C 9H 11D 3D 10H 11S 13D 2S 8H 3H 11C 14C 8S 4C 10D
#
#  cards flipped: 7H 5H 2C 5C 3C
#  cards flipped: 7S 5S 10S 11H 12C
# Player 2  discarded: 7S 5S 5S 2C 10S 5C 11H 3C 12C
# Deck:
# 10C 14H 12S 13C 7D 9D 13H 2D 8C 14D 4D 12H 9S 4S 6C 13S 9C 4H 14S 3S
#
# Deck:
# 8D 6D 6S 2H 12D 7C 9H 11D 3D 10H 11S 13D 2S 8H 3H 11C 14C 8S 4C 10D
#
#  cards flipped: 7H 5H 2C 5C 3C 5D
#  cards flipped: 7S 5S 10S 11H 12C 6H
# Player 2  discarded: 7S 5S 5S 2C 10S 5C 11H 3C 12C 5D 6H
# Deck:
# 14H 12S 13C 7D 9D 13H 2D 8C 14D 4D 12H 9S 4S 6C 13S 9C 4H 14S 3S
#
# Deck:
# 6D 6S 2H 12D 7C 9H 11D 3D 10H 11S 13D 2S 8H 3H 11C 14C 8S 4C 10D
#
#  cards flipped: 7H 5H 2C 5C 3C 5D 10C
#  cards flipped: 7S 5S 10S 11H 12C 6H 8D
# Player 1  discarded: 7H 5H 5H 10C 8D
# Deck:
# 12S 13C 7D 9D 13H 2D 8C 14D 4D 12H 9S 4S 6C 13S 9C 4H 14S 3S
#
# Deck:
# 6S 2H 12D 7C 9H 11D 3D 10H 11S 13D 2S 8H 3H 11C 14C 8S 4C 10D
#
#  cards flipped: 7H 5H 2C 5C 3C 5D 10C 14H
#  cards flipped: 7S 5S 10S 11H 12C 6H 8D 6D
# Player 1  discarded: 7H 5H 5H 10C 8D 14H 6D
# Deck:
# 13C 7D 9D 13H 2D 8C 14D 4D 12H 9S 4S 6C 13S 9C 4H 14S 3S
#
# Deck:
# 2H 12D 7C 9H 11D 3D 10H 11S 13D 2S 8H 3H 11C 14C 8S 4C 10D
#
#  cards flipped: 7H 5H 2C 5C 3C 5D 10C 14H 12S
#  cards flipped: 7S 5S 10S 11H 12C 6H 8D 6D 6S
# Player 1  discarded: 7H 5H 5H 10C 8D 14H 6D 12S 6S
# Deck:
# 7D 9D 13H 2D 8C 14D 4D 12H 9S 4S 6C 13S 9C 4H 14S 3S
#
# Deck:
# 12D 7C 9H 11D 3D 10H 11S 13D 2S 8H 3H 11C 14C 8S 4C 10D
#
#  cards flipped: 7H 5H 2C 5C 3C 5D 10C 14H 12S 13C
#  cards flipped: 7S 5S 10S 11H 12C 6H 8D 6D 6S 2H
# Player 1  discarded: 7H 5H 5H 10C 8D 14H 6D 12S 6S 13C 2H
# Deck:
# 9D 13H 2D 8C 14D 4D 12H 9S 4S 6C 13S 9C 4H 14S 3S
#
# Deck:
# 7C 9H 11D 3D 10H 11S 13D 2S 8H 3H 11C 14C 8S 4C 10D
#
#  cards flipped: 7H 5H 2C 5C 3C 5D 10C 14H 12S 13C 7D
#  cards flipped: 7S 5S 10S 11H 12C 6H 8D 6D 6S 2H 12D

# %%
#returns discard pile to respective players deck
import random
import pygame
from pygameRogers import Game
from pygameRogers import Room
from pygameRogers import GameObject
from pygameRogers import TextRectangle

#Craete a new game-------------------------------------------------------------
g = Game(700,500) #w/ war x = 900 pix

#Color
BLUE = (0,143,213) 
BLACK = (0,0,0) 
WHITE = (255,255,255) 
PASTEL_GREEN = (210,249,237)
DARK_GREEN = (14,99,73)

#Create Resources--------------------------------------------------------------
gameFont1 = g.makeFont("Arial",22)
gameBackground = g.makeBackground(BLUE)

diamondPics = []
for i in range (2,15):
    diamondPics.append(g.makeSpriteImage("Cards\DIAMONDS" + str(i) + ".jpg"))
    
heartPics = []
for i in range (2,15):
    heartPics.append(g.makeSpriteImage("Cards\HEARTS" + str(i) + ".jpg"))
    
spadePics = []
for i in range (2,15):
    spadePics.append(g.makeSpriteImage("Cards\SPADES" + str(i) + ".jpg"))
    
clubPics = []
for i in range (2,15):
    clubPics.append(g.makeSpriteImage("Cards\CLUBS" + str(i) + ".jpg"))
    
topCard = g.makeSpriteImage("Cards\TOP.jpg")

#Create Room-------------------------------------------------------------------
r1  = Room("War",gameBackground)
g.addRoom(r1)

r2 = Room("War 2",gameBackground)
g.addRoom(r2)

#Classes for Game objects------------------------------------------------------
class Card (GameObject):
    def __init__(self, picture, value, suit):
        GameObject.__init__(self,picture)
        
        #Attributes
        self.value = value # 2-14
        self.suit = suit # H, D, C, S
        
    def update(self):
        self.checkMousePressedOnMe(event)
        
        if self.mouseHasPressedOnMe and event.type == pygame.MOUSEBUTTONUP:
             
            lastCard = len(p1Card.played) - 1 
            card_p1_played = p1Card.played[lastCard]
            card_p2_played = p2Card.played[lastCard]
            
            if card_p1_played.value > card_p2_played.value:
                
                p1Card.discardCard(card_p1_played)
                p2Card.discardCard(card_p2_played)
                
                p1_discard.addCard(card_p1_played)
                p1_discard.addCard(card_p2_played)
                
                
                print("Player 1 ",p1_discard)
                
            elif card_p1_played.value < card_p2_played.value:
                
                p1Card.discardCard(card_p1_played)
                p2Card.discardCard(card_p2_played)
                
                p2_discard.addCard(card_p1_played)
                p2_discard.addCard(card_p2_played)
                
                
                print("Player 2 ",p2_discard)
                
            else:
                p1Card.discardCard(card_p1_played)
                p2Card.discardCard(card_p2_played)
                
                p1_discard.addCard(card_p1_played)
                p2_discard.addCard(card_p2_played)
            
                print("Player 1 ",p1_discard)
                print("Player 2 ",p2_discard)
            
            self.mouseHasPressedOnMe = False
            
        
    def __str__(self):
        return str(self.value) + self.suit

class CardDeck(GameObject):
    def __init__(self):
        GameObject.__init__(self)
        
        self.deck = []
        self.p1_deck = []
        self.p2_deck = []
        
        for i in range (0, len(diamondPics)):
            c = Card(diamondPics[i], (i+2), "D")
            self.deck.append(c)
            
        for i in range (0, len(heartPics)):
            c = Card(heartPics[i], (i+2), "H")
            self.deck.append(c)
            
        for i in range (0, len(clubPics)):
            c = Card(clubPics[i], (i+2), "C")
            self.deck.append(c)
            
        for i in range (0, len(spadePics)):
            c = Card(spadePics[i], (i+2), "S")
            self.deck.append(c)

        random.shuffle(self.deck)   
        
        #distribute the cards amoung the 2 players
        for i in range (0,len(self.deck)//2):
            self.p1_deck.append(self.deck[i])
            
        for i in range (len(self.deck)//2,len(self.deck)):
            self.p2_deck.append(self.deck[i])
        
        
        
    def __str__(self):
        s = ""
        
        for card in self.p1_deck:
            s += str(card) + " "
        s = "Deck1:\n" + s + "\n"
        
    
        s2 = ""
        
        for card in self.p2_deck:
            s2 += str(card) + " "
        s2 = "Deck2:\n" + s2 + "\n"
        
        return s + "\t\t\t\t" + s2
    
class PlayerDeck(GameObject):
    #display
    def __init__(self, picture, xPos, yPos, player_deck):
        GameObject.__init__(self,picture)
        
        self.rect.x = xPos
        self.rect.y = yPos
        
        self.player_deck = player_deck
        
    def __str__(self):
        s = ""
        
        for card in self.player_deck:
            s += str(card) + " "
        s = "Deck:\n" + s + "\n"
        return s
    
    def update(self):
        self.checkMousePressedOnMe(event)
        
        if self.mouseHasPressedOnMe and event.type == pygame.MOUSEBUTTONUP:
            
            card = p1_Deck.get_top_card()
            p1Card.flipCardOver(card)
            
            card2 = p2_Deck.get_top_card()
            p2Card.flipCardOver(card2)
            
        
            
       #     print(p1_Deck)
        #    print(p2_Deck)
         #   print(p1Card)
          #  print(p2Card)

          
            self.mouseHasPressedOnMe = False

    
    def get_top_card(self):
        
        if len(self.player_deck) > 0:
            c = self.player_deck[0]
            del self.player_deck[0]
            
            if len(self.player_deck) == 0:
                self.kill()
                
                
                restock = AddToDeckButton("Return Cards", 450, 200, gameFont1, DARK_GREEN, 200, 40, WHITE)
               
                r1.addObject(restock)
                    
        return c
    
    def addCard(self,card):
        self.player_deck.append(card)
        
     
    

class FlipedCard(GameObject):
    
    def __init__(self,xPos,yPos):
        GameObject.__init__(self)
        
        self.xPos = xPos
        self.yPos = yPos
        self.played = []
        
        
    def flipCardOver(self,card):
        self.played.append(card)        
        
        card.rect.x = self.xPos
        card.rect.y = self.yPos
        
        r1.addObject(card)
        
    def discardCard(self, card):
        
        for c in self.played:
            c.kill()
    
    def __str__(self):
         s = " cards flipped: "
         
         if len(self.played) > 0:
             for i in range (0,len(self.played)):
                 s += str(self.played[i]) + " "
             
         return s       
        
class Discardpile(GameObject):
    def __init__(self,xPos,yPos):
        GameObject.__init__(self)
        
        self.playedCards = []
        
        self.rect.x = xPos
        self.rect.y = yPos
        
    def addCard(self,card):
        self.playedCards.append(card)
        
        self.image = card.image
        
 ###################################################   
    def removeCards(self,playerDeck):
        for card in self.playedCards:
            playerDeck.addCard(card)
            
        random.shuffle(playerDeck.player_deck)
        
        self.playedCards.clear()
        self.image = pygame.Surface((0,0))
        self.kill()
 ######################################################       
    def __str__(self):
        s = ""
        if len(self.playedCards) > 0:
            for card in self.playedCards:
                s += str(card) + " "
        s = "discarded: " + s
        return s


class AddToDeckButton(TextRectangle):
    
    def __init__(self, text, xPos, yPos, font, textColor, buttonWitdth, buttonHeight, buttonColor):
    
        TextRectangle.__init__(self, text, xPos, yPos, font, textColor, buttonWitdth, buttonHeight, buttonColor)


    def update(self):
        
        self.checkMousePressedOnMe(event)
        
        if self.mouseHasPressedOnMe and event.type == pygame.MOUSEBUTTONUP:
            
            if len(p1_Deck.player_deck) == 0 and p1_discard.playedCards != 0:
               p1_discard.removeCards(p1_Deck)
               r1.addObject(p1_Deck)
               r1.addObject(p1_discard)
               print("New P1 ",p1_Deck)
               
            if len(p2_Deck.player_deck) == 0 and p2_discard.playedCards != 0: 
               p2_discard.removeCards(p2_Deck)
               r1.addObject(p2_Deck)
               r1.addObject(p2_discard)
               print("New P2",p2_Deck)
               
                
            self.kill()
#Initialize Objects and add them to the room-----------------------------------

play_card_label = TextRectangle("Click either deck to flip cards",15,15,gameFont1,PASTEL_GREEN)
discard_card_label = TextRectangle("Click the card to collect it",145,210,gameFont1,PASTEL_GREEN)


r1.addObject(play_card_label)
r1.addObject(discard_card_label)

d = CardDeck()
r1.addObject(d)

p1_Deck = PlayerDeck(topCard, 70, 50, d.p1_deck)
p2_Deck = PlayerDeck(topCard, 70, 350, d.p2_deck)

r1.addObject(p1_Deck)
r1.addObject(p2_Deck)

p1Card = FlipedCard(185,50)
p2Card = FlipedCard(185,350)

r1.addObject(p1Card)
r1.addObject(p2Card)

p1_discard = Discardpile(430,50) #when screen 900 pix, x = 730
p2_discard = Discardpile(430,350)

r1.addObject(p2_discard)
r1.addObject(p1_discard)


#Start Game--------------------------------------------------------------------
g.start()

#Game Loop
while g.running:
    
    #Limit the game excecution framerate
    dt = g.clock.tick(60)
    
    #Check for events 
    for event in pygame.event.get():
        
        #Quit if user click [x]
        if event.type == pygame.QUIT:
            g.stop()
            
    #Update the gamestate of all objects
    g.currentRoom().updateObjects()
    
    #Render the background to the window surface
    g.currentRoom().renderBackground(g)
    
    #Render the object images to the background
    g.currentRoom().renderObjects(g)
    
    #Draw everything on the screen
    pygame.display.flip()
    
pygame.quit()
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.8.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
#puts discard pile in respective player deck w/o errors
import random
import pygame
from pygameRogers import Game
from pygameRogers import Room
from pygameRogers import GameObject
from pygameRogers import TextRectangle
from pygameRogers import Alarm

#Craete a new game-------------------------------------------------------------
g = Game(700,500) #w/ war x = 900 pix

#Color
BLUE = (0,143,213) 
BLACK = (0,0,0) 
WHITE = (255,255,255) 
PASTEL_GREEN = (210,249,237)
DARK_GREEN = (14,99,73)

#Create Resources--------------------------------------------------------------
gameFont1 = g.makeFont("Arial",22)
gameBackground = g.makeBackground(BLUE)

diamondPics = []
for i in range (2,15):
    diamondPics.append(g.makeSpriteImage("Cards\DIAMONDS" + str(i) + ".jpg"))
    
heartPics = []
for i in range (2,15):
    heartPics.append(g.makeSpriteImage("Cards\HEARTS" + str(i) + ".jpg"))
    
spadePics = []
for i in range (2,15):
    spadePics.append(g.makeSpriteImage("Cards\SPADES" + str(i) + ".jpg"))
    
clubPics = []
for i in range (2,15):
    clubPics.append(g.makeSpriteImage("Cards\CLUBS" + str(i) + ".jpg"))
    
topCard = g.makeSpriteImage("Cards\TOP.jpg")

#Create Room-------------------------------------------------------------------
r1  = Room("War",gameBackground)
g.addRoom(r1)

r2 = Room("War 2",gameBackground)
g.addRoom(r2)

#Classes for Game objects------------------------------------------------------
class Card (GameObject):
    def __init__(self, picture, value, suit):
        GameObject.__init__(self,picture)
        
        #Attributes
        self.value = value # 2-14
        self.suit = suit # H, D, C, S
        
    def update(self):
        self.checkMousePressedOnMe(event)
        
        if self.mouseHasPressedOnMe and event.type == pygame.MOUSEBUTTONUP: #and !p1Card.war 
             
            lastCard = len(p1Card.played) - 1 
            card_p1_played = p1Card.played[lastCard]
            card_p2_played = p2Card.played[lastCard]
            
            if card_p1_played.value > card_p2_played.value:
                
                p1Card.discardCard(card_p1_played)
                p2Card.discardCard(card_p2_played)
                
                p1_discard.addCard(card_p1_played)
                p1_discard.addCard(card_p2_played)
                
                
                
                print("Player 1 ",p1_discard)
                
            elif card_p1_played.value < card_p2_played.value:
                
                p1Card.discardCard(card_p1_played)
                p2Card.discardCard(card_p2_played)
                
                p2_discard.addCard(card_p1_played)
                p2_discard.addCard(card_p2_played)
                
                
                
                print("Player 2 ",p2_discard)
                
            else:
                
                #p1Card.war = True
                p1Card.discardCard(card_p1_played)
                p2Card.discardCard(card_p2_played)
                
                p1_discard.addCard(card_p1_played)
                p2_discard.addCard(card_p2_played)
            
                print("Player 1 ",p1_discard)
                print("Player 2 ",p2_discard)
            
            self.mouseHasPressedOnMe = False
            print("length ",len(p1Card.played))
            
        
    def __str__(self):
        return str(self.value) + self.suit

class CardDeck(GameObject):
    def __init__(self):
        GameObject.__init__(self)
        
        self.deck = []
        self.p1_deck = []
        self.p2_deck = []
        
        for i in range (0, len(diamondPics)):
            c = Card(diamondPics[i], (i+2), "D")
            self.deck.append(c)
            
        for i in range (0, len(heartPics)):
            c = Card(heartPics[i], (i+2), "H")
            self.deck.append(c)
            
        for i in range (0, len(clubPics)):
            c = Card(clubPics[i], (i+2), "C")
            self.deck.append(c)
            
        for i in range (0, len(spadePics)):
            c = Card(spadePics[i], (i+2), "S")
            self.deck.append(c)

        random.shuffle(self.deck)   
        
        #distribute the cards amoung the 2 players
        for i in range (0,len(self.deck)//2):
            self.p1_deck.append(self.deck[i])
            
        for i in range (len(self.deck)//2,len(self.deck)):
            self.p2_deck.append(self.deck[i])
        
        
        
    def __str__(self):
        s = ""
        
        for card in self.p1_deck:
            s += str(card) + " "
        s = "Deck1:\n" + s + "\n"
        
    
        s2 = ""
        
        for card in self.p2_deck:
            s2 += str(card) + " "
        s2 = "Deck2:\n" + s2 + "\n"
        
        return s + "\t\t\t\t" + s2
    
class PlayerDeck(GameObject):
    
    def __init__(self, picture, xPos, yPos, player_deck):
        GameObject.__init__(self,picture)
        
        self.rect.x = xPos
        self.rect.y = yPos
        
        self.player_deck = player_deck
        
        
    def __str__(self):
        s = ""
        
        for card in self.player_deck:
            s += str(card) + " "
        s = "Deck:\n" + s + "\n"
        return s
    
    def update(self):
        self.checkMousePressedOnMe(event)
        
        if self.mouseHasPressedOnMe and event.type == pygame.MOUSEBUTTONUP and len(p1_Deck.player_deck) > 0 and len(p2_Deck.player_deck) > 0 and len(p1Card.played) == 0: #or p1Card.war)
            
            card = p1_Deck.get_top_card()
            p1Card.flipCardOver(card)
            
            card2 = p2_Deck.get_top_card()
            p2Card.flipCardOver(card2)
            
            #if p1Card.war:
                    #p1Card.war = False
            
        
            
       #     print(p1_Deck)
        #    print(p2_Deck)
            print(p1Card)
            print(p2Card)
            print("length:",len(p1Card.played))

          
            self.mouseHasPressedOnMe = False
      
    
    def get_top_card(self):
        
        if len(self.player_deck) > 0:
            c = self.player_deck[0]
            del self.player_deck[0]
            
            if len(self.player_deck) == 0:
                self.kill()
                
                
                restock = AddToDeckButton("Return Cards", 450, 200, gameFont1, DARK_GREEN, 200, 40, WHITE)
               
                r1.addObject(restock)
                    
        return c
    
    def addCard(self,card):
        self.player_deck.append(card)
        
     
    

class FlipedCard(GameObject):
    
    def __init__(self,xPos,yPos):
        GameObject.__init__(self)
        
        self.xPos = xPos
        self.yPos = yPos
        self.played = []
        
        #self.war = False
        
        
    def flipCardOver(self,card):
        self.played.append(card)        
        
        card.rect.x = self.xPos
        card.rect.y = self.yPos
        
        r1.addObject(card)
        
    def discardCard(self, card):
        
        for c in self.played:
            c.kill()
    
        self.played.clear()

    def __str__(self):
         s = " cards flipped: "
         
         if len(self.played) > 0:
             for i in range (0,len(self.played)):
                 s += str(self.played[i]) + " "
             
         return s       
        
class Discardpile(GameObject):
    def __init__(self,xPos,yPos):
        GameObject.__init__(self)
        
        self.playedCards = []
        
        self.rect.x = xPos
        self.rect.y = yPos
        
    def addCard(self,card):
        self.playedCards.append(card)
        
        self.image = card.image
        
 ###################################################   
    def removeCards(self,playerDeck):
        for card in self.playedCards:
            playerDeck.addCard(card)
            
   #     random.shuffle(playerDeck.player_deck)
        
        self.playedCards.clear()
        self.image = pygame.Surface((0,0))
        self.kill()
 ######################################################       
    def __str__(self):
        s = ""
        if len(self.playedCards) > 0:
            for card in self.playedCards:
                s += str(card) + " "
        s = "discarded: " + s
        return s


class AddToDeckButton(TextRectangle):
    
    def __init__(self, text, xPos, yPos, font, textColor, buttonWitdth, buttonHeight, buttonColor):
    
        TextRectangle.__init__(self, text, xPos, yPos, font, textColor, buttonWitdth, buttonHeight, buttonColor)


    def update(self):
        
        self.checkMousePressedOnMe(event)
        
        if self.mouseHasPressedOnMe and event.type == pygame.MOUSEBUTTONUP:
            
            if len(p1_Deck.player_deck) == 0 and len(p1_discard.playedCards) == 0: 
                
                winner_label = TextRectangle("Game Over, Player 2 Won",200,210,gameFont1,DARK_GREEN)
                r2.addObject(winner_label)
                
                g.nextRoom()
                
                
                
            if len(p2_Deck.player_deck) == 0 and len(p2_discard.playedCards) == 0: 
                
                winner_label = TextRectangle("Game Over, Player 1 Won",200,210,gameFont1,DARK_GREEN)
                r2.addObject(winner_label)
                
                g.nextRoom()
            
            if len(p1_Deck.player_deck) == 0 and len(p1_discard.playedCards) != 0:
               p1_discard.removeCards(p1_Deck)
               r1.addObject(p1_Deck)
               r1.addObject(p1_discard)
               print("New P1 ",p1_Deck)
               
            if len(p2_Deck.player_deck) == 0 and len(p2_discard.playedCards) != 0: 
               p2_discard.removeCards(p2_Deck)
               r1.addObject(p2_Deck)
               r1.addObject(p2_discard)
               print("New P2",p2_Deck)
               
            self.kill()
            

    
#Initialize Objects and add them to the room-----------------------------------

play_card_label = TextRectangle("Click either deck to flip cards",15,15,gameFont1,PASTEL_GREEN)
discard_card_label = TextRectangle("Click the card to collect it",145,210,gameFont1,PASTEL_GREEN)


r1.addObject(play_card_label)
r1.addObject(discard_card_label)

d = CardDeck()
r1.addObject(d)

p1_Deck = PlayerDeck(topCard, 70, 50, d.p1_deck)
p2_Deck = PlayerDeck(topCard, 70, 350, d.p2_deck)

r1.addObject(p1_Deck)
r1.addObject(p2_Deck)

p1Card = FlipedCard(185,50)
p2Card = FlipedCard(185,350)

r1.addObject(p1Card)
r1.addObject(p2Card)

p1_discard = Discardpile(430,50) #when screen 900 pix, x = 730
p2_discard = Discardpile(430,350)

r1.addObject(p2_discard)
r1.addObject(p1_discard)


#Start Game--------------------------------------------------------------------
g.start()


#Game Loop
while g.running:
    
    #Limit the game excecution framerate
    dt = g.clock.tick(60)
    
    #Check for events 
    for event in pygame.event.get():
        
        #Quit if user click [x]
        if event.type == pygame.QUIT:
            g.stop()
            
    #Update the gamestate of all objects
    g.currentRoom().updateObjects()
    
    #Render the background to the window surface
    g.currentRoom().renderBackground(g)
    
    #Render the object images to the background
    g.currentRoom().renderObjects(g)
    
    #Draw everything on the screen
    pygame.display.flip()
    
pygame.quit()
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.8.3)
# Hello from the pygame community. https://www.pygame.org/contribute.html
#  cards flipped: 12H
#  cards flipped: 10H
# length: 1

# %%
#war pile appears, flipped card cannot be clicked
import random
import pygame
from pygameRogers import Game
from pygameRogers import Room
from pygameRogers import GameObject
from pygameRogers import TextRectangle
from pygameRogers import Alarm

#Craete a new game-------------------------------------------------------------
g = Game(900,500) #w/ war x = 900 pix

#Color
BLUE = (0,143,213) 
BLACK = (0,0,0) 
WHITE = (255,255,255) 
PASTEL_GREEN = (210,249,237)
DARK_GREEN = (14,99,73)

#Create Resources--------------------------------------------------------------
gameFont1 = g.makeFont("Arial",22)
gameBackground = g.makeBackground(BLUE)

diamondPics = []
for i in range (2,15):
    diamondPics.append(g.makeSpriteImage("Cards\DIAMONDS" + str(i) + ".jpg"))
    
heartPics = []
for i in range (2,15):
    heartPics.append(g.makeSpriteImage("Cards\HEARTS" + str(i) + ".jpg"))
    
spadePics = []
for i in range (2,15):
    spadePics.append(g.makeSpriteImage("Cards\SPADES" + str(i) + ".jpg"))
    
clubPics = []
for i in range (2,15):
    clubPics.append(g.makeSpriteImage("Cards\CLUBS" + str(i) + ".jpg"))
    
topCard = g.makeSpriteImage("Cards\TOP.jpg")

warCards = g.makeSpriteImage("Cards\TOP3.jpg")
#Create Room-------------------------------------------------------------------
r1  = Room("War",gameBackground)
g.addRoom(r1)

r2 = Room("War 2",gameBackground)
g.addRoom(r2)

#Classes for Game objects------------------------------------------------------
class Card (GameObject):
    def __init__(self, picture, value, suit):
        GameObject.__init__(self,picture)
        
        #Attributes
        self.value = value # 2-14
        self.suit = suit # H, D, C, S
        
    def update(self):
        self.checkMousePressedOnMe(event)
        
        if self.mouseHasPressedOnMe and event.type == pygame.MOUSEBUTTONUP and not p1Card.war: 
             
            lastCard = len(p1Card.played) - 1 
            card_p1_played = p1Card.played[lastCard]
            card_p2_played = p2Card.played[lastCard]
            
            if card_p1_played.value > card_p2_played.value:
                
                #if war >> put in discard
                    #else: 
                
                p1Card.discardCard(card_p1_played)
                p2Card.discardCard(card_p2_played)
                
                p1_discard.addCard(card_p1_played)
                p1_discard.addCard(card_p2_played)
                
                
                
        #        print("Player 1 ",p1_discard)
                
            elif card_p1_played.value < card_p2_played.value:
                
                p1Card.discardCard(card_p1_played)
                p2Card.discardCard(card_p2_played)
                
                p2_discard.addCard(card_p1_played)
                p2_discard.addCard(card_p2_played)
                
                
                
         #       print("Player 2 ",p2_discard)
                
            else:
                
                p1Card.war = True
            #    p1Card.discardCard(card_p1_played)
             #   p2Card.discardCard(card_p2_played)
                
             #   p1_discard.addCard(card_p1_played)
              #  p2_discard.addCard(card_p2_played)
                
                p1_war.get_3_cards(p1_Deck)
                p2_war.get_3_cards(p2_Deck)
                
                print(p1_war)
                print(p2_war)
                
                print(p1_Deck)
                print(p2_Deck)
         #       print("Player 1 ",p1_discard)
         #       print("Player 2 ",p2_discard)
            
            self.mouseHasPressedOnMe = False
            
        
    def __str__(self):
        return str(self.value) + self.suit

class CardDeck(GameObject):
    def __init__(self):
        GameObject.__init__(self)
        
        self.deck = []
        self.p1_deck = []
        self.p2_deck = []
        
        for i in range (0, len(diamondPics)):
            c = Card(diamondPics[i], (i+2), "D")
            self.deck.append(c)
            
        for i in range (0, len(heartPics)):
            c = Card(heartPics[i], (i+2), "H")
            self.deck.append(c)
            
        for i in range (0, len(clubPics)):
            c = Card(clubPics[i], (i+2), "C")
            self.deck.append(c)
            
        for i in range (0, len(spadePics)):
            c = Card(spadePics[i], (i+2), "S")
            self.deck.append(c)

        random.shuffle(self.deck)   
        
        #distribute the cards amoung the 2 players
        for i in range (0,len(self.deck)//2):
            self.p1_deck.append(self.deck[i])
            
        for i in range (len(self.deck)//2,len(self.deck)):
            self.p2_deck.append(self.deck[i])
        
        
        
    def __str__(self):
        s = ""
        
        for card in self.p1_deck:
            s += str(card) + " "
        s = "Deck1:\n" + s + "\n"
        
    
        s2 = ""
        
        for card in self.p2_deck:
            s2 += str(card) + " "
        s2 = "Deck2:\n" + s2 + "\n"
        
        return s + "\t\t\t\t" + s2
    
class PlayerDeck(GameObject):
    
    def __init__(self, picture, xPos, yPos, player_deck):
        GameObject.__init__(self,picture)
        
        self.rect.x = xPos
        self.rect.y = yPos
        
        self.player_deck = player_deck
        
        
    def __str__(self):
        s = ""
        
        for card in self.player_deck:
            s += str(card) + " "
        s = "Deck:\n" + s + "\n"
        return s
    
    def update(self):
        self.checkMousePressedOnMe(event)
        
        if self.mouseHasPressedOnMe and event.type == pygame.MOUSEBUTTONUP  and len(p1_Deck.player_deck) > 0 and len(p2_Deck.player_deck) > 0 and (len(p1Card.played) == 0 or p1Card.war):   
            
            card = p1_Deck.get_top_card()
            p1Card.flipCardOver(card)
            
            card2 = p2_Deck.get_top_card()
            p2Card.flipCardOver(card2)
         
            
             
             
            
            if p1Card.war:
                    p1Card.war = False
            
        
            
            print(p1_Deck)
            print(p2_Deck)
      #      print(p1Card)
       #     print(p2Card)
            

          
            self.mouseHasPressedOnMe = False
      
    
    def get_top_card(self):
        
        if len(self.player_deck) > 0:
            c = self.player_deck[0]
            del self.player_deck[0]
            
            if len(self.player_deck) == 0:
                self.kill()
                
                
                restock = AddToDeckButton("Return Cards", 450, 200, gameFont1, DARK_GREEN, 200, 40, WHITE)
               
                r1.addObject(restock)
                    
        return c
    
    def addCard(self,card):
        self.player_deck.append(card)
        
     
    

class FlipedCard(GameObject):
    
    def __init__(self,xPos,yPos):
        GameObject.__init__(self)
        
        self.xPos = xPos
        self.yPos = yPos
        self.played = []
        
        self.war = False
        
        
    def flipCardOver(self,card):
        self.played.append(card)        
        
        card.rect.x = self.xPos
        card.rect.y = self.yPos
        
        r1.addObject(card)
        
    def discardCard(self, card):
        
        for c in self.played:
            c.kill()
    
        self.played.clear()

    def __str__(self):
         s = " cards flipped: "
         
         if len(self.played) > 0:
             for i in range (0,len(self.played)):
                 s += str(self.played[i]) + " "
             
         return s       
        
class Discardpile(GameObject):
    def __init__(self,xPos,yPos):
        GameObject.__init__(self)
        
        self.playedCards = []
        
        self.rect.x = xPos
        self.rect.y = yPos
        
    def addCard(self,card):
        self.playedCards.append(card)
        
        self.image = card.image
        
 ###################################################   
    def removeCards(self,playerDeck):
        for card in self.playedCards:
            playerDeck.addCard(card)
            
        random.shuffle(playerDeck.player_deck)
        
        self.playedCards.clear()
        self.image = pygame.Surface((0,0))
        self.kill()
 ######################################################       
    def __str__(self):
        s = ""
        if len(self.playedCards) > 0:
            for card in self.playedCards:
                s += str(card) + " "
        s = "discarded: " + s
        return s


class AddToDeckButton(TextRectangle):
    
    def __init__(self, text, xPos, yPos, font, textColor, buttonWitdth, buttonHeight, buttonColor):
    
        TextRectangle.__init__(self, text, xPos, yPos, font, textColor, buttonWitdth, buttonHeight, buttonColor)


    def update(self):
        
        self.checkMousePressedOnMe(event)
        
        if self.mouseHasPressedOnMe and event.type == pygame.MOUSEBUTTONUP:
            
            if len(p1_Deck.player_deck) == 0 and len(p1_discard.playedCards) == 0: 
                
                winner_label = TextRectangle("Game Over, Player 2 Won",500,210,gameFont1,DARK_GREEN)
                r2.addObject(winner_label)
                
                g.nextRoom()
                
                
                
            if len(p2_Deck.player_deck) == 0 and len(p2_discard.playedCards) == 0: 
                
                winner_label = TextRectangle("Game Over, Player 1 Won",500,210,gameFont1,DARK_GREEN)
                r2.addObject(winner_label)
                
                g.nextRoom()
            
            if len(p1_Deck.player_deck) == 0 and len(p1_discard.playedCards) != 0:
               p1_discard.removeCards(p1_Deck)
               r1.addObject(p1_Deck)
               r1.addObject(p1_discard)
               print("New P1 ",p1_Deck)
               
            if len(p2_Deck.player_deck) == 0 and len(p2_discard.playedCards) != 0: 
               p2_discard.removeCards(p2_Deck)
               r1.addObject(p2_Deck)
               r1.addObject(p2_discard)
               print("New P2",p2_Deck)
               
            self.kill()
            
class WarPile(GameObject):
    def __init__(self,picture,xPos,yPos):
        GameObject.__init__(self)
        
        self.rect.x = xPos
        self.rect.y = yPos
        self.picture = picture
        
        self.card_list = []
        
        self.timer = Alarm()
        
    def get_3_cards(self,playerDeck):
        
        if len(playerDeck.player_deck) >= 3:
            
            for i in range (0,3):
                c = playerDeck.get_top_card()
                self.card_list.append(c)
                            
                self.image = self.picture
                
    def __str__(self):
        s = ""
        
        for card in self.card_list:
            s += str(card) + " "
            
        s = "war pile: " + s
        return s
#Initialize Objects and add them to the room-----------------------------------

play_card_label = TextRectangle("Click either deck to flip cards",15,15,gameFont1,PASTEL_GREEN)
discard_card_label = TextRectangle("Click the card to collect it",145,210,gameFont1,PASTEL_GREEN)


r1.addObject(play_card_label)
r1.addObject(discard_card_label)

d = CardDeck()
r1.addObject(d)

p1_Deck = PlayerDeck(topCard, 70, 50, d.p1_deck)
p2_Deck = PlayerDeck(topCard, 70, 350, d.p2_deck)

r1.addObject(p1_Deck)
r1.addObject(p2_Deck)

p1Card = FlipedCard(185,50)
p2Card = FlipedCard(185,350)

r1.addObject(p1Card)
r1.addObject(p2Card)

p1_discard = Discardpile(730,50) #when screen 900 pix, x = 730
p2_discard = Discardpile(730,350)

r1.addObject(p2_discard)
r1.addObject(p1_discard)

p1_war = WarPile(warCards, 265, 50)
p2_war = WarPile(warCards, 265,350)

r1.addObject(p1_war)
r1.addObject(p2_war)

#Start Game--------------------------------------------------------------------
g.start()


#Game Loop
while g.running:
    
    #Limit the game excecution framerate
    dt = g.clock.tick(60)
    
    #Check for events 
    for event in pygame.event.get():
        
        #Quit if user click [x]
        if event.type == pygame.QUIT:
            g.stop()
            
    #Update the gamestate of all objects
    g.currentRoom().updateObjects()
    
    #Render the background to the window surface
    g.currentRoom().renderBackground(g)
    
    #Render the object images to the background
    g.currentRoom().renderObjects(g)
    
    #Draw everything on the screen
    pygame.display.flip()
    
pygame.quit()
# Out:
# Deck:
# 4S 14H 2H 3C 13C 9S 10H 5D 10D 2S 5S 6C 2C 7C 10C 4D 4H 11D 5H 3D 2D 9D 3S 13H 12D
#
# Deck:
# 11C 4C 8H 14C 14D 8D 5C 13S 7D 10S 6D 9C 13D 11H 7S 12H 9H 14S 6S 12S 8S 8C 12C 6H 11S
#
# Deck:
# 14H 2H 3C 13C 9S 10H 5D 10D 2S 5S 6C 2C 7C 10C 4D 4H 11D 5H 3D 2D 9D 3S 13H 12D
#
# Deck:
# 4C 8H 14C 14D 8D 5C 13S 7D 10S 6D 9C 13D 11H 7S 12H 9H 14S 6S 12S 8S 8C 12C 6H 11S
#
# Deck:
# 2H 3C 13C 9S 10H 5D 10D 2S 5S 6C 2C 7C 10C 4D 4H 11D 5H 3D 2D 9D 3S 13H 12D
#
# Deck:
# 8H 14C 14D 8D 5C 13S 7D 10S 6D 9C 13D 11H 7S 12H 9H 14S 6S 12S 8S 8C 12C 6H 11S
#
# Deck:
# 3C 13C 9S 10H 5D 10D 2S 5S 6C 2C 7C 10C 4D 4H 11D 5H 3D 2D 9D 3S 13H 12D
#
# Deck:
# 14C 14D 8D 5C 13S 7D 10S 6D 9C 13D 11H 7S 12H 9H 14S 6S 12S 8S 8C 12C 6H 11S
#
# Deck:
# 13C 9S 10H 5D 10D 2S 5S 6C 2C 7C 10C 4D 4H 11D 5H 3D 2D 9D 3S 13H 12D
#
# Deck:
# 14D 8D 5C 13S 7D 10S 6D 9C 13D 11H 7S 12H 9H 14S 6S 12S 8S 8C 12C 6H 11S
#
# Deck:
# 9S 10H 5D 10D 2S 5S 6C 2C 7C 10C 4D 4H 11D 5H 3D 2D 9D 3S 13H 12D
#
# Deck:
# 8D 5C 13S 7D 10S 6D 9C 13D 11H 7S 12H 9H 14S 6S 12S 8S 8C 12C 6H 11S
#
# Deck:
# 10H 5D 10D 2S 5S 6C 2C 7C 10C 4D 4H 11D 5H 3D 2D 9D 3S 13H 12D
#
# Deck:
# 5C 13S 7D 10S 6D 9C 13D 11H 7S 12H 9H 14S 6S 12S 8S 8C 12C 6H 11S
#
# Deck:
# 5D 10D 2S 5S 6C 2C 7C 10C 4D 4H 11D 5H 3D 2D 9D 3S 13H 12D
#
# Deck:
# 13S 7D 10S 6D 9C 13D 11H 7S 12H 9H 14S 6S 12S 8S 8C 12C 6H 11S
#
# Deck:
# 10D 2S 5S 6C 2C 7C 10C 4D 4H 11D 5H 3D 2D 9D 3S 13H 12D
#
# Deck:
# 7D 10S 6D 9C 13D 11H 7S 12H 9H 14S 6S 12S 8S 8C 12C 6H 11S
#
# Deck:
# 2S 5S 6C 2C 7C 10C 4D 4H 11D 5H 3D 2D 9D 3S 13H 12D
#
# Deck:
# 10S 6D 9C 13D 11H 7S 12H 9H 14S 6S 12S 8S 8C 12C 6H 11S
#
# Deck:
# 5S 6C 2C 7C 10C 4D 4H 11D 5H 3D 2D 9D 3S 13H 12D
#
# Deck:
# 6D 9C 13D 11H 7S 12H 9H 14S 6S 12S 8S 8C 12C 6H 11S
#
# Deck:
# 6C 2C 7C 10C 4D 4H 11D 5H 3D 2D 9D 3S 13H 12D
#
# Deck:
# 9C 13D 11H 7S 12H 9H 14S 6S 12S 8S 8C 12C 6H 11S
#
# Deck:
# 2C 7C 10C 4D 4H 11D 5H 3D 2D 9D 3S 13H 12D
#
# Deck:
# 13D 11H 7S 12H 9H 14S 6S 12S 8S 8C 12C 6H 11S
#
# Deck:
# 7C 10C 4D 4H 11D 5H 3D 2D 9D 3S 13H 12D
#
# Deck:
# 11H 7S 12H 9H 14S 6S 12S 8S 8C 12C 6H 11S
#
# Deck:
# 10C 4D 4H 11D 5H 3D 2D 9D 3S 13H 12D
#
# Deck:
# 7S 12H 9H 14S 6S 12S 8S 8C 12C 6H 11S
#
# Deck:
# 4D 4H 11D 5H 3D 2D 9D 3S 13H 12D
#
# Deck:
# 12H 9H 14S 6S 12S 8S 8C 12C 6H 11S
#
# Deck:
# 4H 11D 5H 3D 2D 9D 3S 13H 12D
#
# Deck:
# 9H 14S 6S 12S 8S 8C 12C 6H 11S
#
# Deck:
# 11D 5H 3D 2D 9D 3S 13H 12D
#
# Deck:
# 14S 6S 12S 8S 8C 12C 6H 11S
#
# Deck:
# 5H 3D 2D 9D 3S 13H 12D
#
# Deck:
# 6S 12S 8S 8C 12C 6H 11S
#
# Deck:
# 3D 2D 9D 3S 13H 12D
#
# Deck:
# 12S 8S 8C 12C 6H 11S
#
# Deck:
# 2D 9D 3S 13H 12D
#
# Deck:
# 8S 8C 12C 6H 11S
#
# Deck:
# 9D 3S 13H 12D
#
# Deck:
# 8C 12C 6H 11S
#
# Deck:
# 3S 13H 12D
#
# Deck:
# 12C 6H 11S
#
# Deck:
# 13H 12D
#
# Deck:
# 6H 11S
#
# Deck:
# 12D
#
# Deck:
# 11S
#
# Deck:
#
#
# Deck:
#
#
# New P1  Deck:
# 7S 10C 10D 9S 13H 12D 14H 11S 10H 9D 7D 6H 4C 5C 8D 8C
#
# New P2 Deck:
# 6D 10S 12H 9C 2H 5S 7H 13S 3S 9H 12C 3D 5H 11C 2C 13D 8H 5D 4D 3C 13C 11D 2D 3H 14C 12S 11H 4H 6C 6S 14D 14S 7C 8S 2S 4S
#
# Deck:
# 10C 10D 9S 13H 12D 14H 11S 10H 9D 7D 6H 4C 5C 8D 8C
#
# Deck:
# 10S 12H 9C 2H 5S 7H 13S 3S 9H 12C 3D 5H 11C 2C 13D 8H 5D 4D 3C 13C 11D 2D 3H 14C 12S 11H 4H 6C 6S 14D 14S 7C 8S 2S 4S
#
# Deck:
# 10D 9S 13H 12D 14H 11S 10H 9D 7D 6H 4C 5C 8D 8C
#
# Deck:
# 12H 9C 2H 5S 7H 13S 3S 9H 12C 3D 5H 11C 2C 13D 8H 5D 4D 3C 13C 11D 2D 3H 14C 12S 11H 4H 6C 6S 14D 14S 7C 8S 2S 4S
#
# war pile: 10D 9S 13H
# war pile: 12H 9C 2H
# Deck:
# 12D 14H 11S 10H 9D 7D 6H 4C 5C 8D 8C
#
# Deck:
# 5S 7H 13S 3S 9H 12C 3D 5H 11C 2C 13D 8H 5D 4D 3C 13C 11D 2D 3H 14C 12S 11H 4H 6C 6S 14D 14S 7C 8S 2S 4S
#
# Deck:
# 14H 11S 10H 9D 7D 6H 4C 5C 8D 8C
#
# Deck:
# 7H 13S 3S 9H 12C 3D 5H 11C 2C 13D 8H 5D 4D 3C 13C 11D 2D 3H 14C 12S 11H 4H 6C 6S 14D 14S 7C 8S 2S 4S
#
# Deck:
# 11S 10H 9D 7D 6H 4C 5C 8D 8C
#
# Deck:
# 13S 3S 9H 12C 3D 5H 11C 2C 13D 8H 5D 4D 3C 13C 11D 2D 3H 14C 12S 11H 4H 6C 6S 14D 14S 7C 8S 2S 4S

# %%
#war works here!
import random
import pygame
from pygameRogers import Game
from pygameRogers import Room
from pygameRogers import GameObject
from pygameRogers import TextRectangle
from pygameRogers import Alarm

#Craete a new game-------------------------------------------------------------
g = Game(900,500) #w/ war x = 900 pix

#Color
BLUE = (0,143,213) 
BLACK = (0,0,0) 
WHITE = (255,255,255) 
PASTEL_GREEN = (210,249,237)
DARK_GREEN = (14,99,73)

#Create Resources--------------------------------------------------------------
gameFont1 = g.makeFont("Arial",22)
gameBackground = g.makeBackground(BLUE)

diamondPics = []
for i in range (2,15):
    diamondPics.append(g.makeSpriteImage("Cards\DIAMONDS" + str(i) + ".jpg"))
    
heartPics = []
for i in range (2,15):
    heartPics.append(g.makeSpriteImage("Cards\HEARTS" + str(i) + ".jpg"))
    
spadePics = []
for i in range (2,15):
    spadePics.append(g.makeSpriteImage("Cards\SPADES" + str(i) + ".jpg"))
    
clubPics = []
for i in range (2,15):
    clubPics.append(g.makeSpriteImage("Cards\CLUBS" + str(i) + ".jpg"))
    
topCard = g.makeSpriteImage("Cards\TOP.jpg")

warCards = g.makeSpriteImage("Cards\TOP3.jpg")
#Create Room-------------------------------------------------------------------
r1  = Room("War",gameBackground)
g.addRoom(r1)

r2 = Room("War 2",gameBackground)
g.addRoom(r2)

#Classes for Game objects------------------------------------------------------
class Card (GameObject):
    def __init__(self, picture, value, suit):
        GameObject.__init__(self,picture)
        
        #Attributes
        self.value = value # 2-14
        self.suit = suit # H, D, C, S
        
    def update(self):
        self.checkMousePressedOnMe(event)
        
        if self.mouseHasPressedOnMe and event.type == pygame.MOUSEBUTTONUP and not p1Card.war and len(p1Card.played) > 0: 
            
         
            lastCard = len(p1Card.played) - 1 
            card_p1_played = p1Card.played[lastCard]
            card_p2_played = p2Card.played[lastCard]
            
            
            if card_p1_played.value > card_p2_played.value:
                
                if len(p1_war.card_list) > 0:
                    
                 #   p1_war.card_list.append(card_p1_played)
                  #  p2_war.card_list.append(card_p2_played)
                    
                    p1_war.put_in_discard(p1_discard)
                    p2_war.put_in_discard(p1_discard)
                    
                    print("p1 ",p1_war)
                    print("p2 ",p2_war)
                else:
                    p1Card.discardCard(card_p1_played)
                    p2Card.discardCard(card_p2_played)
                
                    p1_discard.addCard(card_p1_played)
                    p1_discard.addCard(card_p2_played)
                
                
                
                print("Player 1 ",p1_discard)
                
            elif card_p1_played.value < card_p2_played.value:
                
                if len(p2_war.card_list) > 0:
                    
                  #  p1_war.card_list.append(card_p1_played)
                   # p2_war.card_list.append(card_p2_played)
                    
                    p1_war.put_in_discard(p2_discard)
                    p2_war.put_in_discard(p2_discard)
                    
                    print("p1 ",p1_war)
                    print("p2 ",p2_war)
                
                else:
                    p1Card.discardCard(card_p1_played)
                    p2Card.discardCard(card_p2_played)
                
                    p2_discard.addCard(card_p1_played)
                    p2_discard.addCard(card_p2_played)
                
                
                
                print("Player 2 ",p2_discard)
                
            else:
                
                p1Card.war = True
                
                r1.addObject(p1_war)
                r1.addObject(p2_war)
                        
                if len(p1Card.played) < 2:  
                    p1_war.get_3_cards(p1_Deck)
                    p2_war.get_3_cards(p2_Deck)
                
                p1_war.card_list.append(card_p1_played)
                p2_war.card_list.append(card_p2_played)
                
                print("p1: ",p1_war)
                print("p2: ",p2_war)
                
             #   print(p1_Deck)
              #  print(p2_Deck)
         #       print("Player 1 ",p1_discard)
         #       print("Player 2 ",p2_discard)
            
            self.mouseHasPressedOnMe = False
            
        
    def __str__(self):
        return str(self.value) + self.suit

class CardDeck(GameObject):
    def __init__(self):
        GameObject.__init__(self)
        
        self.deck = []
        self.p1_deck = []
        self.p2_deck = []
        
        for i in range (0, len(diamondPics)):
            c = Card(diamondPics[i], (i+2), "D")
            self.deck.append(c)
            
        for i in range (0, len(heartPics)):
            c = Card(heartPics[i], (i+2), "H")
            self.deck.append(c)
            
        for i in range (0, len(clubPics)):
            c = Card(clubPics[i], (i+2), "C")
            self.deck.append(c)
            
        for i in range (0, len(spadePics)):
            c = Card(spadePics[i], (i+2), "S")
            self.deck.append(c)

        random.shuffle(self.deck)   
        
        #distribute the cards amoung the 2 players
        for i in range (0,len(self.deck)//2):
            self.p1_deck.append(self.deck[i])
            
        for i in range (len(self.deck)//2,len(self.deck)):
            self.p2_deck.append(self.deck[i])
        
        
        
    def __str__(self):
        s = ""
        
        for card in self.p1_deck:
            s += str(card) + " "
        s = "Deck1:\n" + s + "\n"
        
    
        s2 = ""
        
        for card in self.p2_deck:
            s2 += str(card) + " "
        s2 = "Deck2:\n" + s2 + "\n"
        
        return s + "\t\t\t\t" + s2
    
class PlayerDeck(GameObject):
    
    def __init__(self, picture, xPos, yPos, player_deck):
        GameObject.__init__(self,picture)
        
        self.rect.x = xPos
        self.rect.y = yPos
        
        self.player_deck = player_deck
        
        
    def __str__(self):
        s = ""
        
        for card in self.player_deck:
            s += str(card) + " "
        s = "Deck:\n" + s + "\n"
        return s
    
    def update(self):
        self.checkMousePressedOnMe(event)
        
        if self.mouseHasPressedOnMe and event.type == pygame.MOUSEBUTTONUP  and len(p1_Deck.player_deck) > 0 and len(p2_Deck.player_deck) > 0 and (len(p1Card.played) == 0 or p1Card.war):   
                        
            card = p1_Deck.get_top_card()
            card2 = p2_Deck.get_top_card()
            
            if p1Card.war:
                
           #     x = 383*p1_war.war_count
                
                p1Card.flipCardOver(card,383)
                p2Card.flipCardOver(card2,383) 
                
                
                p1Card.war = False
            
            else:
                p1Card.flipCardOver(card)
                p2Card.flipCardOver(card2)    
              
                
                
            
            
     
         #   print(p1_Deck)
          #  print(p2_Deck)
            print(p1Card)
            print(p2Card)
            

          
            self.mouseHasPressedOnMe = False
      
    
    def get_top_card(self):
        
        if len(self.player_deck) > 0:
            c = self.player_deck[0]
            del self.player_deck[0]
            
            if len(self.player_deck) == 0:
                self.kill()
                
                
                restock = AddToDeckButton("Return Cards", 450, 200, gameFont1, DARK_GREEN, 200, 40, WHITE)
               
                r1.addObject(restock)
                    
        return c
    
    def addCard(self,card):
        self.player_deck.append(card)
        
     
    

class FlipedCard(GameObject):
    
    def __init__(self,xPos,yPos):
        GameObject.__init__(self)
        
        self.xPos = xPos
        self.yPos = yPos
        self.played = []
        
        self.war = False
        
        
    def flipCardOver(self,card,newX = None):
        
        
        if self.war:
            card.rect.x = newX 
        else:
            card.rect.x = self.xPos
        
        self.played.append(card)        
        
        card.rect.y = self.yPos
        
        r1.addObject(card)
            
            
        
    def discardCard(self, card):
        
        for c in self.played:
            c.kill()
    
        self.played.clear()

    def __str__(self):
         s = " cards flipped: "
         
         if len(self.played) > 0:
             for i in range (0,len(self.played)):
                 s += str(self.played[i]) + " "
             
         return s       
        
class Discardpile(GameObject):
    def __init__(self,xPos,yPos):
        GameObject.__init__(self)
        
        self.playedCards = []
        
        self.rect.x = xPos
        self.rect.y = yPos
        
    def addCard(self,card):
        self.playedCards.append(card)
        
        self.image = card.image
        
 ###################################################   
    def removeCards(self,playerDeck):
        for card in self.playedCards:
            playerDeck.addCard(card)
            
        random.shuffle(playerDeck.player_deck)
        
        self.playedCards.clear()
        self.image = pygame.Surface((0,0))
        self.kill()
 ######################################################       
    def __str__(self):
        s = ""
        if len(self.playedCards) > 0:
            for card in self.playedCards:
                s += str(card) + " "
        s = "discarded: " + s
        return s


class AddToDeckButton(TextRectangle):
    
    def __init__(self, text, xPos, yPos, font, textColor, buttonWitdth, buttonHeight, buttonColor):
    
        TextRectangle.__init__(self, text, xPos, yPos, font, textColor, buttonWitdth, buttonHeight, buttonColor)


    def update(self):
        
        self.checkMousePressedOnMe(event)
        
        if self.mouseHasPressedOnMe and event.type == pygame.MOUSEBUTTONUP:
            
            if len(p1_Deck.player_deck) == 0 and len(p1_discard.playedCards) == 0: 
                
                winner_label = TextRectangle("Game Over, Player 2 Won",500,210,gameFont1,DARK_GREEN)
                r2.addObject(winner_label)
                
                g.nextRoom()
                
                
                
            if len(p2_Deck.player_deck) == 0 and len(p2_discard.playedCards) == 0: 
                
                winner_label = TextRectangle("Game Over, Player 1 Won",500,210,gameFont1,DARK_GREEN)
                r2.addObject(winner_label)
                
                g.nextRoom()
            
            if len(p1_Deck.player_deck) == 0 and len(p1_discard.playedCards) != 0:
               p1_discard.removeCards(p1_Deck)
               r1.addObject(p1_Deck)
               r1.addObject(p1_discard)
               print("New P1 ",p1_Deck)
               
            if len(p2_Deck.player_deck) == 0 and len(p2_discard.playedCards) != 0: 
               p2_discard.removeCards(p2_Deck)
               r1.addObject(p2_Deck)
               r1.addObject(p2_discard)
               print("New P2",p2_Deck)
               
            self.kill()
            
class WarPile(GameObject):
    def __init__(self,picture,xPos,yPos):
        GameObject.__init__(self)
        
       # self.war_count = 0
        
        self.rect.x = xPos
        self.rect.y = yPos
        self.picture = picture
        
        self.card_list = []
        
        self.timer = Alarm()
        
    def get_3_cards(self,playerDeck):
        
        if len(playerDeck.player_deck) >= 3:
            
            for i in range (0,3):
                c = playerDeck.get_top_card()
                self.card_list.append(c)
                            
                self.image = self.picture
                
        #    self.war_count += 1
        
    def put_in_discard(self,p_discard):
        for i in range (0,len(self.card_list)):
            p_discard.addCard(self.card_list[i])
            
            
            self.card_list[i].kill()
            
            
        self.card_list.clear()
        self.kill()
    

            
    def __str__(self):
        s = ""
        
        for card in self.card_list:
            s += str(card) + " "
            
        s = "war pile: " + s
        return s
#Initialize Objects and add them to the room-----------------------------------

play_card_label = TextRectangle("Click either deck to flip cards",15,15,gameFont1,PASTEL_GREEN)
discard_card_label = TextRectangle("Click cards to collect",145,210,gameFont1,PASTEL_GREEN)


r1.addObject(play_card_label)
r1.addObject(discard_card_label)

d = CardDeck()
r1.addObject(d)

p1_Deck = PlayerDeck(topCard, 70, 50, d.p1_deck)
p2_Deck = PlayerDeck(topCard, 70, 350, d.p2_deck)

r1.addObject(p1_Deck)
r1.addObject(p2_Deck)

p1Card = FlipedCard(185,50)
p2Card = FlipedCard(185,350)

r1.addObject(p1Card)
r1.addObject(p2Card)

p1_discard = Discardpile(780,50) #when screen 900 pix, x = 730
p2_discard = Discardpile(780,350)

r1.addObject(p2_discard)
r1.addObject(p1_discard)

p1_war = WarPile(warCards, 265, 50)
p2_war = WarPile(warCards, 265,350)

r1.addObject(p1_war)
r1.addObject(p2_war)


#Start Game--------------------------------------------------------------------
g.start()


#Game Loop
while g.running:
    
    #Limit the game excecution framerate
    dt = g.clock.tick(60)
    
    #Check for events 
    for event in pygame.event.get():
        
        #Quit if user click [x]
        if event.type == pygame.QUIT:
            g.stop()
            
    #Update the gamestate of all objects
    g.currentRoom().updateObjects()
    
    #Render the background to the window surface
    g.currentRoom().renderBackground(g)
    
    #Render the object images to the background
    g.currentRoom().renderObjects(g)
    
    #Draw everything on the screen
    pygame.display.flip()
    
pygame.quit()
# Out:
#  cards flipped: 6C
#  cards flipped: 11C
# Player 2  discarded: 6C 11C
#  cards flipped: 6D
#  cards flipped: 14S
# Player 2  discarded: 6C 11C 6D 14S
#  cards flipped: 2S
#  cards flipped: 10D
# Player 2  discarded: 6C 11C 6D 14S 2S 10D
#  cards flipped: 5D
#  cards flipped: 8S
# Player 2  discarded: 6C 11C 6D 14S 2S 10D 5D 8S
#  cards flipped: 2D
#  cards flipped: 5C
# Player 2  discarded: 6C 11C 6D 14S 2S 10D 5D 8S 2D 5C
#  cards flipped: 3H
#  cards flipped: 6H
# Player 2  discarded: 6C 11C 6D 14S 2S 10D 5D 8S 2D 5C 3H 6H
#  cards flipped: 11S
#  cards flipped: 13H
# Player 2  discarded: 6C 11C 6D 14S 2S 10D 5D 8S 2D 5C 3H 6H 11S 13H
#  cards flipped: 4D
#  cards flipped: 7C
# Player 2  discarded: 6C 11C 6D 14S 2S 10D 5D 8S 2D 5C 3H 6H 11S 13H 4D 7C
#  cards flipped: 3S
#  cards flipped: 5H
# Player 2  discarded: 6C 11C 6D 14S 2S 10D 5D 8S 2D 5C 3H 6H 11S 13H 4D 7C 3S 5H
#  cards flipped: 3C
#  cards flipped: 9C
# Player 2  discarded: 6C 11C 6D 14S 2S 10D 5D 8S 2D 5C 3H 6H 11S 13H 4D 7C 3S 5H 3C 9C
#  cards flipped: 10S
#  cards flipped: 11D
# Player 2  discarded: 6C 11C 6D 14S 2S 10D 5D 8S 2D 5C 3H 6H 11S 13H 4D 7C 3S 5H 3C 9C 10S 11D
#  cards flipped: 9H
#  cards flipped: 12H
# Player 2  discarded: 6C 11C 6D 14S 2S 10D 5D 8S 2D 5C 3H 6H 11S 13H 4D 7C 3S 5H 3C 9C 10S 11D 9H 12H
#  cards flipped: 6S
#  cards flipped: 12D
# Player 2  discarded: 6C 11C 6D 14S 2S 10D 5D 8S 2D 5C 3H 6H 11S 13H 4D 7C 3S 5H 3C 9C 10S 11D 9H 12H 6S 12D
#  cards flipped: 8C
#  cards flipped: 9D
# Player 2  discarded: 6C 11C 6D 14S 2S 10D 5D 8S 2D 5C 3H 6H 11S 13H 4D 7C 3S 5H 3C 9C 10S 11D 9H 12H 6S 12D 8C 9D
#  cards flipped: 8H
#  cards flipped: 2H
# Player 1  discarded: 8H 2H
#  cards flipped: 7H
#  cards flipped: 13S
# Player 2  discarded: 6C 11C 6D 14S 2S 10D 5D 8S 2D 5C 3H 6H 11S 13H 4D 7C 3S 5H 3C 9C 10S 11D 9H 12H 6S 12D 8C 9D 7H 13S
#  cards flipped: 14H
#  cards flipped: 4C
# Player 1  discarded: 8H 2H 14H 4C
#  cards flipped: 14D
#  cards flipped: 7S
# Player 1  discarded: 8H 2H 14H 4C 14D 7S
#  cards flipped: 5S
#  cards flipped: 12S
# Player 2  discarded: 6C 11C 6D 14S 2S 10D 5D 8S 2D 5C 3H 6H 11S 13H 4D 7C 3S 5H 3C 9C 10S 11D 9H 12H 6S 12D 8C 9D 7H 13S 5S 12S
#  cards flipped: 13D
#  cards flipped: 11H
# Player 1  discarded: 8H 2H 14H 4C 14D 7S 13D 11H
#  cards flipped: 9S
#  cards flipped: 13C
# Player 2  discarded: 6C 11C 6D 14S 2S 10D 5D 8S 2D 5C 3H 6H 11S 13H 4D 7C 3S 5H 3C 9C 10S 11D 9H 12H 6S 12D 8C 9D 7H 13S 5S 12S 9S 13C
#  cards flipped: 7D
#  cards flipped: 14C
# Player 2  discarded: 6C 11C 6D 14S 2S 10D 5D 8S 2D 5C 3H 6H 11S 13H 4D 7C 3S 5H 3C 9C 10S 11D 9H 12H 6S 12D 8C 9D 7H 13S 5S 12S 9S 13C 7D 14C
#  cards flipped: 4S
#  cards flipped: 3D
# Player 1  discarded: 8H 2H 14H 4C 14D 7S 13D 11H 4S 3D
#  cards flipped: 10C
#  cards flipped: 2C
# Player 1  discarded: 8H 2H 14H 4C 14D 7S 13D 11H 4S 3D 10C 2C
#  cards flipped: 8D
#  cards flipped: 4H
# Player 1  discarded: 8H 2H 14H 4C 14D 7S 13D 11H 4S 3D 10C 2C 8D 4H
#  cards flipped: 12C
#  cards flipped: 10H
# Player 1  discarded: 8H 2H 14H 4C 14D 7S 13D 11H 4S 3D 10C 2C 8D 4H 12C 10H
# New P1  Deck:
# 7S 13D 3D 10C 12C 4S 4C 2H 2C 14H 4H 14D 8D 8H 10H 11H
#
# New P2 Deck:
# 6H 7D 8S 9S 6S 12S 9C 5S 11D 9D 13C 12D 2D 5C 3S 5D 14C 12H 9H 6C 5H 7C 11S 10S 10D 4D 3H 8C 11C 3C 2S 7H 14S 13H 13S 6D
#
#  cards flipped: 7S
#  cards flipped: 6H
# Player 1  discarded: 7S 6H
#  cards flipped: 13D
#  cards flipped: 7D
# Player 1  discarded: 7S 6H 13D 7D
#  cards flipped: 3D
#  cards flipped: 8S
# Player 2  discarded: 3D 8S
#  cards flipped: 10C
#  cards flipped: 9S
# Player 1  discarded: 7S 6H 13D 7D 10C 9S
#  cards flipped: 12C
#  cards flipped: 6S
# Player 1  discarded: 7S 6H 13D 7D 10C 9S 12C 6S
#  cards flipped: 4S
#  cards flipped: 12S
# Player 2  discarded: 3D 8S 4S 12S
#  cards flipped: 4C
#  cards flipped: 9C
# Player 2  discarded: 3D 8S 4S 12S 4C 9C
#  cards flipped: 2H
#  cards flipped: 5S
# Player 2  discarded: 3D 8S 4S 12S 4C 9C 2H 5S
#  cards flipped: 2C
#  cards flipped: 11D
# Player 2  discarded: 3D 8S 4S 12S 4C 9C 2H 5S 2C 11D
#  cards flipped: 14H
#  cards flipped: 9D
# Player 1  discarded: 7S 6H 13D 7D 10C 9S 12C 6S 14H 9D
#  cards flipped: 4H
#  cards flipped: 13C
# Player 2  discarded: 3D 8S 4S 12S 4C 9C 2H 5S 2C 11D 4H 13C
#  cards flipped: 14D
#  cards flipped: 12D
# Player 1  discarded: 7S 6H 13D 7D 10C 9S 12C 6S 14H 9D 14D 12D
#  cards flipped: 8D
#  cards flipped: 2D
# Player 1  discarded: 7S 6H 13D 7D 10C 9S 12C 6S 14H 9D 14D 12D 8D 2D
#  cards flipped: 8H
#  cards flipped: 5C
# Player 1  discarded: 7S 6H 13D 7D 10C 9S 12C 6S 14H 9D 14D 12D 8D 2D 8H 5C
#  cards flipped: 10H
#  cards flipped: 3S
# Player 1  discarded: 7S 6H 13D 7D 10C 9S 12C 6S 14H 9D 14D 12D 8D 2D 8H 5C 10H 3S
#  cards flipped: 11H
#  cards flipped: 5D
# Player 1  discarded: 7S 6H 13D 7D 10C 9S 12C 6S 14H 9D 14D 12D 8D 2D 8H 5C 10H 3S 11H 5D
# New P1  Deck:
# 5D 7D 12D 10C 14D 11H 9S 3S 10H 13D 12C 5C 7S 14H 6S 8H 6H 9D 8D 2D
#
#  cards flipped: 5D
#  cards flipped: 14C
# Player 2  discarded: 3D 8S 4S 12S 4C 9C 2H 5S 2C 11D 4H 13C 5D 14C
#  cards flipped: 7D
#  cards flipped: 12H
# Player 2  discarded: 3D 8S 4S 12S 4C 9C 2H 5S 2C 11D 4H 13C 5D 14C 7D 12H
#  cards flipped: 12D
#  cards flipped: 9H
# Player 1  discarded: 12D 9H
#  cards flipped: 10C
#  cards flipped: 6C
# Player 1  discarded: 12D 9H 10C 6C
#  cards flipped: 14D
#  cards flipped: 5H
# Player 1  discarded: 12D 9H 10C 6C 14D 5H
#  cards flipped: 11H
#  cards flipped: 7C
# Player 1  discarded: 12D 9H 10C 6C 14D 5H 11H 7C
#  cards flipped: 9S
#  cards flipped: 11S
# Player 2  discarded: 3D 8S 4S 12S 4C 9C 2H 5S 2C 11D 4H 13C 5D 14C 7D 12H 9S 11S
#  cards flipped: 3S
#  cards flipped: 10S
# Player 2  discarded: 3D 8S 4S 12S 4C 9C 2H 5S 2C 11D 4H 13C 5D 14C 7D 12H 9S 11S 3S 10S
#  cards flipped: 10H
#  cards flipped: 10D
# p1:  war pile: 13D 12C 5C 10H
# p2:  war pile: 4D 3H 8C 10D
#  cards flipped: 10H 7S
#  cards flipped: 10D 11C
# p1  war pile:
# p2  war pile:
# Player 2  discarded: 3D 8S 4S 12S 4C 9C 2H 5S 2C 11D 4H 13C 5D 14C 7D 12H 9S 11S 3S 10S 13D 12C 5C 10H 4D 3H 8C 10D
# Player 2  discarded: 3D 8S 4S 12S 4C 9C 2H 5S 2C 11D 4H 13C 5D 14C 7D 12H 9S 11S 3S 10S 13D 12C 5C 10H 4D 3H 8C 10D 7S 11C
#  cards flipped: 14H
#  cards flipped: 3C
# Player 1  discarded: 12D 9H 10C 6C 14D 5H 11H 7C 14H 3C
#  cards flipped: 6S
#  cards flipped: 2S
# Player 1  discarded: 12D 9H 10C 6C 14D 5H 11H 7C 14H 3C 6S 2S
#  cards flipped: 8H
#  cards flipped: 7H
# Player 1  discarded: 12D 9H 10C 6C 14D 5H 11H 7C 14H 3C 6S 2S 8H 7H
#  cards flipped: 6H
#  cards flipped: 14S
# Player 2  discarded: 3D 8S 4S 12S 4C 9C 2H 5S 2C 11D 4H 13C 5D 14C 7D 12H 9S 11S 3S 10S 13D 12C 5C 10H 4D 3H 8C 10D 7S 11C 6H 14S
#  cards flipped: 9D
#  cards flipped: 13H
# Player 2  discarded: 3D 8S 4S 12S 4C 9C 2H 5S 2C 11D 4H 13C 5D 14C 7D 12H 9S 11S 3S 10S 13D 12C 5C 10H 4D 3H 8C 10D 7S 11C 6H 14S 9D 13H
#  cards flipped: 8D
#  cards flipped: 13S
# Player 2  discarded: 3D 8S 4S 12S 4C 9C 2H 5S 2C 11D 4H 13C 5D 14C 7D 12H 9S 11S 3S 10S 13D 12C 5C 10H 4D 3H 8C 10D 7S 11C 6H 14S 9D 13H 8D 13S
#  cards flipped: 2D
#  cards flipped: 6D
# Player 2  discarded: 3D 8S 4S 12S 4C 9C 2H 5S 2C 11D 4H 13C 5D 14C 7D 12H 9S 11S 3S 10S 13D 12C 5C 10H 4D 3H 8C 10D 7S 11C 6H 14S 9D 13H 8D 13S 2D 6D
# New P1  Deck:
# 3C 9H 7C 10C 7H 14D 2S 12D 6C 11H 8H 5H 14H 6S
#
# New P2 Deck:
# 12C 14S 10H 13S 13D 4S 8S 9C 7S 4H 11D 2D 12S 9S 3H 11C 3S 2H 6D 11S 8D 13C 14C 12H 4C 10S 10D 6H 8C 5C 13H 4D 3D 9D 7D 5D 2C 5S
#
#  cards flipped: 3C
#  cards flipped: 12C
# Player 2  discarded: 3C 12C
#  cards flipped: 9H
#  cards flipped: 14S
# Player 2  discarded: 3C 12C 9H 14S
#  cards flipped: 7C
#  cards flipped: 10H
# Player 2  discarded: 3C 12C 9H 14S 7C 10H
#  cards flipped: 10C
#  cards flipped: 13S
# Player 2  discarded: 3C 12C 9H 14S 7C 10H 10C 13S
#  cards flipped: 7H
#  cards flipped: 13D
# Player 2  discarded: 3C 12C 9H 14S 7C 10H 10C 13S 7H 13D
#  cards flipped: 14D
#  cards flipped: 4S
# Player 1  discarded: 14D 4S
#  cards flipped: 2S
#  cards flipped: 8S
# Player 2  discarded: 3C 12C 9H 14S 7C 10H 10C 13S 7H 13D 2S 8S
#  cards flipped: 12D
#  cards flipped: 9C
# Player 1  discarded: 14D 4S 12D 9C
#  cards flipped: 6C
#  cards flipped: 7S
# Player 2  discarded: 3C 12C 9H 14S 7C 10H 10C 13S 7H 13D 2S 8S 6C 7S
#  cards flipped: 11H
#  cards flipped: 4H
# Player 1  discarded: 14D 4S 12D 9C 11H 4H
#  cards flipped: 8H
#  cards flipped: 11D
# Player 2  discarded: 3C 12C 9H 14S 7C 10H 10C 13S 7H 13D 2S 8S 6C 7S 8H 11D
#  cards flipped: 5H
#  cards flipped: 2D
# Player 1  discarded: 14D 4S 12D 9C 11H 4H 5H 2D
#  cards flipped: 14H
#  cards flipped: 12S
# Player 1  discarded: 14D 4S 12D 9C 11H 4H 5H 2D 14H 12S
#  cards flipped: 6S
#  cards flipped: 9S
# Player 2  discarded: 3C 12C 9H 14S 7C 10H 10C 13S 7H 13D 2S 8S 6C 7S 8H 11D 6S 9S
# New P1  Deck:
# 4H 2D 14D 5H 9C 14H 12D 11H 12S 4S
#
#  cards flipped: 4H
#  cards flipped: 3H
# Player 1  discarded: 4H 3H
#  cards flipped: 2D
#  cards flipped: 11C
# Player 2  discarded: 3C 12C 9H 14S 7C 10H 10C 13S 7H 13D 2S 8S 6C 7S 8H 11D 6S 9S 2D 11C
#  cards flipped: 14D
#  cards flipped: 3S
# Player 1  discarded: 4H 3H 14D 3S
#  cards flipped: 5H
#  cards flipped: 2H
# Player 1  discarded: 4H 3H 14D 3S 5H 2H
#  cards flipped: 9C
#  cards flipped: 6D
# Player 1  discarded: 4H 3H 14D 3S 5H 2H 9C 6D
#  cards flipped: 14H
#  cards flipped: 11S
# Player 1  discarded: 4H 3H 14D 3S 5H 2H 9C 6D 14H 11S
#  cards flipped: 12D
#  cards flipped: 8D
# Player 1  discarded: 4H 3H 14D 3S 5H 2H 9C 6D 14H 11S 12D 8D
#  cards flipped: 11H
#  cards flipped: 13C
# Player 2  discarded: 3C 12C 9H 14S 7C 10H 10C 13S 7H 13D 2S 8S 6C 7S 8H 11D 6S 9S 2D 11C 11H 13C
#  cards flipped: 12S
#  cards flipped: 14C
# Player 2  discarded: 3C 12C 9H 14S 7C 10H 10C 13S 7H 13D 2S 8S 6C 7S 8H 11D 6S 9S 2D 11C 11H 13C 12S 14C
#  cards flipped: 4S
#  cards flipped: 12H
# Player 2  discarded: 3C 12C 9H 14S 7C 10H 10C 13S 7H 13D 2S 8S 6C 7S 8H 11D 6S 9S 2D 11C 11H 13C 12S 14C 4S 12H
# New P1  Deck:
# 6D 14H 3H 9C 11S 3S 8D 12D 2H 14D 4H 5H
#
#  cards flipped: 6D
#  cards flipped: 4C
# Player 1  discarded: 6D 4C
#  cards flipped: 14H
#  cards flipped: 10S
# Player 1  discarded: 6D 4C 14H 10S
#  cards flipped: 3H
#  cards flipped: 10D
# Player 2  discarded: 3C 12C 9H 14S 7C 10H 10C 13S 7H 13D 2S 8S 6C 7S 8H 11D 6S 9S 2D 11C 11H 13C 12S 14C 4S 12H 3H 10D
#  cards flipped: 9C
#  cards flipped: 6H
# Player 1  discarded: 6D 4C 14H 10S 9C 6H
#  cards flipped: 11S
#  cards flipped: 8C
# Player 1  discarded: 6D 4C 14H 10S 9C 6H 11S 8C
#  cards flipped: 3S
#  cards flipped: 5C
# Player 2  discarded: 3C 12C 9H 14S 7C 10H 10C 13S 7H 13D 2S 8S 6C 7S 8H 11D 6S 9S 2D 11C 11H 13C 12S 14C 4S 12H 3H 10D 3S 5C
#  cards flipped: 8D
#  cards flipped: 13H
# Player 2  discarded: 3C 12C 9H 14S 7C 10H 10C 13S 7H 13D 2S 8S 6C 7S 8H 11D 6S 9S 2D 11C 11H 13C 12S 14C 4S 12H 3H 10D 3S 5C 8D 13H
#  cards flipped: 12D
#  cards flipped: 4D
# Player 1  discarded: 6D 4C 14H 10S 9C 6H 11S 8C 12D 4D
#  cards flipped: 2H
#  cards flipped: 3D
# Player 2  discarded: 3C 12C 9H 14S 7C 10H 10C 13S 7H 13D 2S 8S 6C 7S 8H 11D 6S 9S 2D 11C 11H 13C 12S 14C 4S 12H 3H 10D 3S 5C 8D 13H 2H 3D
#  cards flipped: 14D
#  cards flipped: 9D
# Player 1  discarded: 6D 4C 14H 10S 9C 6H 11S 8C 12D 4D 14D 9D
#  cards flipped: 4H
#  cards flipped: 7D
# Player 2  discarded: 3C 12C 9H 14S 7C 10H 10C 13S 7H 13D 2S 8S 6C 7S 8H 11D 6S 9S 2D 11C 11H 13C 12S 14C 4S 12H 3H 10D 3S 5C 8D 13H 2H 3D 4H 7D
#  cards flipped: 5H
#  cards flipped: 5D
# p1:  war pile: 5H
# p2:  war pile: 5D
# New P1  Deck:
# 11S 14D 4D 9C 14H 4C 8C 6D 12D 9D 6H 10S
#
#  cards flipped: 5H 11S
#  cards flipped: 5D 2C
# p1  war pile:
# p2  war pile:
# Player 1  discarded: 5H 5D
# Player 1  discarded: 5H 5D 11S 2C
#  cards flipped: 14D
#  cards flipped: 5S
# Player 1  discarded: 5H 5D 11S 2C 14D 5S
# New P2 Deck:
# 14C 3S 9S 11C 2H 8S 6C 7C 13C 10C 6S 12C 2S 5C 8H 13S 4S 2D 12S 3D 14S 3C 13D 11D 10H 7S 12H 8D 7H 10D 11H 7D 13H 9H 4H 3H
#
#  cards flipped: 4D
#  cards flipped: 14C
# Player 2  discarded: 4D 14C
#  cards flipped: 9C
#  cards flipped: 3S
# Player 1  discarded: 5H 5D 11S 2C 14D 5S 9C 3S
#  cards flipped: 14H
#  cards flipped: 9S
# Player 1  discarded: 5H 5D 11S 2C 14D 5S 9C 3S 14H 9S
#  cards flipped: 4C
#  cards flipped: 11C
# Player 2  discarded: 4D 14C 4C 11C
#  cards flipped: 8C
#  cards flipped: 2H
# Player 1  discarded: 5H 5D 11S 2C 14D 5S 9C 3S 14H 9S 8C 2H
#  cards flipped: 6D
#  cards flipped: 8S
# Player 2  discarded: 4D 14C 4C 11C 6D 8S
#  cards flipped: 12D
#  cards flipped: 6C
# Player 1  discarded: 5H 5D 11S 2C 14D 5S 9C 3S 14H 9S 8C 2H 12D 6C
#  cards flipped: 9D
#  cards flipped: 7C
# Player 1  discarded: 5H 5D 11S 2C 14D 5S 9C 3S 14H 9S 8C 2H 12D 6C 9D 7C
#  cards flipped: 6H
#  cards flipped: 13C
# Player 2  discarded: 4D 14C 4C 11C 6D 8S 6H 13C
#  cards flipped: 10S
#  cards flipped: 10C
# p1:  war pile: 10S
# p2:  war pile: 6S 12C 2S 10C
# New P1  Deck:
# 2H 6C 12D 9C 9S 2C 8C 9D 5S 5H 11S 7C 3S 14H 14D 5D
#
#  cards flipped: 10S 2H
#  cards flipped: 10C 5C
# p1  war pile:
# p2  war pile:
# Player 2  discarded: 4D 14C 4C 11C 6D 8S 6H 13C 10S 6S 12C 2S 10C
# Player 2  discarded: 4D 14C 4C 11C 6D 8S 6H 13C 10S 6S 12C 2S 10C 2H 5C
#  cards flipped: 6C
#  cards flipped: 8H
# Player 2  discarded: 4D 14C 4C 11C 6D 8S 6H 13C 10S 6S 12C 2S 10C 2H 5C 6C 8H
#  cards flipped: 12D
#  cards flipped: 13S
# Player 2  discarded: 4D 14C 4C 11C 6D 8S 6H 13C 10S 6S 12C 2S 10C 2H 5C 6C 8H 12D 13S
#  cards flipped: 9C
#  cards flipped: 4S
# Player 1  discarded: 9C 4S
#  cards flipped: 9S
#  cards flipped: 2D
# Player 1  discarded: 9C 4S 9S 2D
#  cards flipped: 2C
#  cards flipped: 12S
# Player 2  discarded: 4D 14C 4C 11C 6D 8S 6H 13C 10S 6S 12C 2S 10C 2H 5C 6C 8H 12D 13S 2C 12S
#  cards flipped: 8C
#  cards flipped: 3D
# Player 1  discarded: 9C 4S 9S 2D 8C 3D
#  cards flipped: 9D
#  cards flipped: 14S
# Player 2  discarded: 4D 14C 4C 11C 6D 8S 6H 13C 10S 6S 12C 2S 10C 2H 5C 6C 8H 12D 13S 2C 12S 9D 14S
#  cards flipped: 5S
#  cards flipped: 3C
# Player 1  discarded: 9C 4S 9S 2D 8C 3D 5S 3C
#  cards flipped: 5H
#  cards flipped: 13D
# Player 2  discarded: 4D 14C 4C 11C 6D 8S 6H 13C 10S 6S 12C 2S 10C 2H 5C 6C 8H 12D 13S 2C 12S 9D 14S 5H 13D
#  cards flipped: 11S
#  cards flipped: 11D
# p1:  war pile: 7C 3S 14H 11S
# p2:  war pile: 10H 7S 12H 11D
#  cards flipped: 11S 14D
#  cards flipped: 11D 8D
# p1  war pile:
# p2  war pile:
# Player 1  discarded: 9C 4S 9S 2D 8C 3D 5S 3C 7C 3S 14H 11S 10H 7S 12H 11D
# Player 1  discarded: 9C 4S 9S 2D 8C 3D 5S 3C 7C 3S 14H 11S 10H 7S 12H 11D 14D 8D
#  cards flipped: 5D
#  cards flipped: 7H
# Player 2  discarded: 4D 14C 4C 11C 6D 8S 6H 13C 10S 6S 12C 2S 10C 2H 5C 6C 8H 12D 13S 2C 12S 9D 14S 5H 13D 5D 7H
# New P1  Deck:
# 3C 2D 12H 3S 4S 8D 14D 7S 7C 9S 11S 8C 10H 14H 3D 11D 5S 9C
#
#  cards flipped: 3C
#  cards flipped: 10D
# Player 2  discarded: 4D 14C 4C 11C 6D 8S 6H 13C 10S 6S 12C 2S 10C 2H 5C 6C 8H 12D 13S 2C 12S 9D 14S 5H 13D 5D 7H 3C 10D
#  cards flipped: 2D
#  cards flipped: 11H
# Player 2  discarded: 4D 14C 4C 11C 6D 8S 6H 13C 10S 6S 12C 2S 10C 2H 5C 6C 8H 12D 13S 2C 12S 9D 14S 5H 13D 5D 7H 3C 10D 2D 11H
#  cards flipped: 12H
#  cards flipped: 7D
# Player 1  discarded: 12H 7D
#  cards flipped: 3S
#  cards flipped: 13H
# Player 2  discarded: 4D 14C 4C 11C 6D 8S 6H 13C 10S 6S 12C 2S 10C 2H 5C 6C 8H 12D 13S 2C 12S 9D 14S 5H 13D 5D 7H 3C 10D 2D 11H 3S 13H
#  cards flipped: 4S
#  cards flipped: 9H
# Player 2  discarded: 4D 14C 4C 11C 6D 8S 6H 13C 10S 6S 12C 2S 10C 2H 5C 6C 8H 12D 13S 2C 12S 9D 14S 5H 13D 5D 7H 3C 10D 2D 11H 3S 13H 4S 9H
#  cards flipped: 8D
#  cards flipped: 4H
# Player 1  discarded: 12H 7D 8D 4H
#  cards flipped: 14D
#  cards flipped: 3H
# Player 1  discarded: 12H 7D 8D 4H 14D 3H
# New P2 Deck:
# 6S 5D 12D 7H 6D 13D 11H 6H 4C 2D 3S 10C 5C 4S 2S 2H 4D 3C 9D 8H 9H 10D 2C 8S 5H 11C 13S 6C 14C 13C 12C 12S 14S 13H 10S
#
#  cards flipped: 7S
#  cards flipped: 6S
# Player 1  discarded: 12H 7D 8D 4H 14D 3H 7S 6S
#  cards flipped: 7C
#  cards flipped: 5D
# Player 1  discarded: 12H 7D 8D 4H 14D 3H 7S 6S 7C 5D
#  cards flipped: 9S
#  cards flipped: 12D
# Player 2  discarded: 9S 12D
#  cards flipped: 11S
#  cards flipped: 7H
# Player 1  discarded: 12H 7D 8D 4H 14D 3H 7S 6S 7C 5D 11S 7H
#  cards flipped: 8C
#  cards flipped: 6D
# Player 1  discarded: 12H 7D 8D 4H 14D 3H 7S 6S 7C 5D 11S 7H 8C 6D
#  cards flipped: 10H
#  cards flipped: 13D
# Player 2  discarded: 9S 12D 10H 13D
#  cards flipped: 14H
#  cards flipped: 11H
# Player 1  discarded: 12H 7D 8D 4H 14D 3H 7S 6S 7C 5D 11S 7H 8C 6D 14H 11H
#  cards flipped: 3D
#  cards flipped: 6H
# Player 2  discarded: 9S 12D 10H 13D 3D 6H
#  cards flipped: 11D
#  cards flipped: 4C
# Player 1  discarded: 12H 7D 8D 4H 14D 3H 7S 6S 7C 5D 11S 7H 8C 6D 14H 11H 11D 4C
#  cards flipped: 5S
#  cards flipped: 2D
# Player 1  discarded: 12H 7D 8D 4H 14D 3H 7S 6S 7C 5D 11S 7H 8C 6D 14H 11H 11D 4C 5S 2D
#  cards flipped: 9C
#  cards flipped: 3S
# Player 1  discarded: 12H 7D 8D 4H 14D 3H 7S 6S 7C 5D 11S 7H 8C 6D 14H 11H 11D 4C 5S 2D 9C 3S
# New P1  Deck:
# 6D 2D 9C 8C 14H 3H 4H 3S 7S 7D 6S 11D 7H 14D 5D 11S 4C 12H 7C 8D 11H 5S
#
#  cards flipped: 6D
#  cards flipped: 10C
# Player 2  discarded: 9S 12D 10H 13D 3D 6H 6D 10C
#  cards flipped: 2D
#  cards flipped: 5C
# Player 2  discarded: 9S 12D 10H 13D 3D 6H 6D 10C 2D 5C
#  cards flipped: 9C
#  cards flipped: 4S
# Player 1  discarded: 9C 4S
#  cards flipped: 8C
#  cards flipped: 2S
# Player 1  discarded: 9C 4S 8C 2S
#  cards flipped: 14H
#  cards flipped: 2H
# Player 1  discarded: 9C 4S 8C 2S 14H 2H
#  cards flipped: 3H
#  cards flipped: 4D
# Player 2  discarded: 9S 12D 10H 13D 3D 6H 6D 10C 2D 5C 3H 4D
#  cards flipped: 4H
#  cards flipped: 3C
# Player 1  discarded: 9C 4S 8C 2S 14H 2H 4H 3C
#  cards flipped: 3S
#  cards flipped: 9D
# Player 2  discarded: 9S 12D 10H 13D 3D 6H 6D 10C 2D 5C 3H 4D 3S 9D
#  cards flipped: 7S
#  cards flipped: 8H
# Player 2  discarded: 9S 12D 10H 13D 3D 6H 6D 10C 2D 5C 3H 4D 3S 9D 7S 8H
#  cards flipped: 7D
#  cards flipped: 9H
# Player 2  discarded: 9S 12D 10H 13D 3D 6H 6D 10C 2D 5C 3H 4D 3S 9D 7S 8H 7D 9H
#  cards flipped: 6S
#  cards flipped: 10D
# Player 2  discarded: 9S 12D 10H 13D 3D 6H 6D 10C 2D 5C 3H 4D 3S 9D 7S 8H 7D 9H 6S 10D
#  cards flipped: 11D
#  cards flipped: 2C
# Player 1  discarded: 9C 4S 8C 2S 14H 2H 4H 3C 11D 2C
#  cards flipped: 7H
#  cards flipped: 8S
# Player 2  discarded: 9S 12D 10H 13D 3D 6H 6D 10C 2D 5C 3H 4D 3S 9D 7S 8H 7D 9H 6S 10D 7H 8S
#  cards flipped: 14D
#  cards flipped: 5H
# Player 1  discarded: 9C 4S 8C 2S 14H 2H 4H 3C 11D 2C 14D 5H
#  cards flipped: 5D
#  cards flipped: 11C
# Player 2  discarded: 9S 12D 10H 13D 3D 6H 6D 10C 2D 5C 3H 4D 3S 9D 7S 8H 7D 9H 6S 10D 7H 8S 5D 11C
#  cards flipped: 11S
#  cards flipped: 13S
# Player 2  discarded: 9S 12D 10H 13D 3D 6H 6D 10C 2D 5C 3H 4D 3S 9D 7S 8H 7D 9H 6S 10D 7H 8S 5D 11C 11S 13S
